# %% [markdown]
# # DINGO Tutorial
#
# **Welcome to the DINGO tutorial!**
#
# This notebook provides an introduction to the DINGO machine-learning package for gravitational wave (GW) parameter estimation. It shows how to train a DINGO model from scratch, or use an already-trained model to obtain posterior samples for GW data. We hope that this will serve as a starting point for those interested in using DINGO.
#
# For a more general introduction to neural posterior estimation of gravitational waves (without DINGO), see the tutorial ["GW Parameter Inference with Machine Learning"](https://github.com/stephengreen/gw-school-corfu-2023).
#
# Since it takes several days to train a production-level DINGO model (14 GW parameters, ~100 million network parameters, ~10 million training examples), we make several simplifications:
# - Restrict the parameter space to two parameters (chirp mass and the mass ratio).
# - Use a much smaller network and training dataset.
# This will give reduced performance, but can be run in real time.
#
# ## Tutorial Structure
# 1. Generating a waveform dataset
# 2. Generating a noise dataset
# 3. Training
# 4. Inference on injections
# 5. Inference on a real event with `dingo_pipe`
# 6. Inference with a pre-trained DINGO model (from Zenodo)
#
# Update 21.10.2025: If you run the code in a Google Colab notebook, you have to downgrade the python version since [`bilby-pipe` currently has to use `python<3.12.7`](https://git.ligo.org/lscsoft/bilby_pipe/-/merge_requests/660). To do this, click `Runtime` -> `Change runtime type` -> Select `2025.07` as the `Runtime version`.
#
# To run on GPU with Colab, make sure that `Runtime` -> `Change runtime type` -> GPU.
# To run on CPU, change `device = cuda` to `device = cpu` in training and inference settings.

# %% [markdown]
# ## 0. Installation
#
# We use `pip`, but dingo can also be installed using `conda`.

# %%
# %%capture
# !pip3 install dingo-gw

# %% [markdown]
# To check whether `dingo` is correctly installed and ready to use, run:

# %%
import warnings
warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
import lal

import dingo
print(dingo.__version__) # Should be >= 0.8.3
# Out:
# 0.9.6

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pickle
import yaml

# %% [markdown]
# Prepare folder structure for tutorial:

# %%
# Remove automatically created folder 'sample_data'
if os.path.isdir("sample_data"):
    os.system("rm -rf sample_data")
# Create folders required for the tutorial
os.makedirs('01_training_data/asd_dataset', exist_ok=True)
os.makedirs('01_training_data/waveform_dataset', exist_ok=True)
os.makedirs('02_training', exist_ok=True)
os.makedirs('03_inference/injection', exist_ok=True)
os.makedirs('04_exercise/lum_dist_marginalization', exist_ok=True)
os.makedirs('04_exercise/with_lum_dist', exist_ok=True)
os.makedirs('05_pretrained_model/init_train_dir', exist_ok=True)
os.makedirs('05_pretrained_model/main_train_dir', exist_ok=True)

# %% [markdown]
# ## 1. Generating a wavefrom dataset
# **Step 1: Prepare settings file**
#
# DINGO uses YAML files to configure all settings for generating training data and training models.
#
# A waveform dataset settings file specifies the following:
# - **domain**: Supported domain types are `UniformFrequencyDomain` and `MultibandedFrequencyDomain`. Specifies, e.g., frequency domain within the range $[f_\mathrm{min}, f_\mathrm{max}]$ and $\delta f$. DINGO currently does not support training on time domain directly. Data from time-domain waveform generators is transformed and saved in the frequency domain.
# - **waveform_generator**: Specify waveform approximant (e.g., IMRPhenomPv2, IMRPhenomXPHM, SEOBNRv4PHM, SEOBNRv5PHM) and reference frequency. Note that SEOBNRv5 waveforms require `pyseobnr` to be installed separately (optional).
# - **intrinsic_prior**: The parameter space is split into intrinsic and extrinsic components: *Intrinsic* parameters refer to those that are needed to generate waveform polarizations. *Extrinsic* parameters refer to those parameters that can be sampled and applied rapidly during training. Luminosity distance and time of coalescence are considered as both intrinsic and extrinsic. They are needed to generate polarizations, but they can also be easily transformed during training to augment the dataset. We therefore fix them to fiducial values for generating polarizations.
# - **num_samples**: Number of waveforms to generate. In a production setting, it is recommended to train a model with (at least) $5 \cdot 10^6$ waveforms, with larger parameter space requiring more samples.
# - **compression**: For large datasets, it is recommended to save compressed waveforms using a [singular-value decomposition (SVD)](https://en.wikipedia.org/wiki/Singular_value_decomposition). Since we only generate a dataset with $10^4$ waveforms, we do not apply the compression. Details about the SVD settings can be found [here](https://dingo-gw.readthedocs.io/en/latest/waveform_dataset.html#generating-a-simple-dataset).
#
# *For this tutorial, we analyze only chirp mass and the mass ratio, fixing all other parameters*
#
# More information about generating the waveform dataset can be found in the sections [Generating Waveforms](https://dingo-gw.readthedocs.io/en/latest/generating_waveforms.html) and [Building a waveform dataset](https://dingo-gw.readthedocs.io/en/latest/waveform_dataset.html) of the DINGO documentation.
#
# For more details on how to parallelize this step over multiple cores on a `htcondor` cluster, you can find more information in one of the [production tutorials](https://dingo-gw.readthedocs.io/en/latest/example_npe_model.html).

# %%
waveform_dataset_settings = """
domain:
  type: UniformFrequencyDomain
  f_min: 20.0
  f_max: 256.0
  delta_f: 0.5 # Expressions like 1.0/8.0 would require eval and are not supported

waveform_generator:
  approximant: IMRPhenomPv2
  f_ref: 20.0
  spin_conversion_phase: 0.0   # Reference phase when converting from spin angles to Cartesian spins. If None, use phase parameter.
  # f_start: 15.0  # Optional setting useful for EOB waveforms. Overrides f_min when generating waveforms.

# Dataset only samples over intrinsic parameters. Extrinsic parameters are chosen at train time.
intrinsic_prior:
  chirp_mass: bilby.gw.prior.UniformInComponentsChirpMass(minimum=15.0, maximum=50.0)
  mass_ratio: bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0)
  theta_jn: 2.624497413635254
  tilt_1: 2.0111560821533203
  tilt_2: 1.0743615627288818
  a_1: 0.925635814666748
  a_2: 0.5538952350616455
  phi_jl: 5.561878204345703
  phase: 0.9604566579018894
  # Reference values for fixed (extrinsic) parameters. These are needed to generate a waveform.
  luminosity_distance: 100.0  # Mpc
  geocent_time: 0.0 # s

# Dataset size
num_samples: 10_000

compression: None
"""
waveform_dataset_settings = yaml.safe_load(waveform_dataset_settings)
with open('01_training_data/waveform_dataset/waveform_dataset_settings.yaml', 'w') as outfile:
    yaml.dump(waveform_dataset_settings, outfile, default_flow_style=False)

# %% [markdown]
# **Step 2: Generate waveform dataset**
#
# To generate the waveform dataset, execute the following command:

# %%
# !dingo_generate_dataset --settings 01_training_data/waveform_dataset/waveform_dataset_settings.yaml --out_file 01_training_data/waveform_dataset/waveform_dataset.hdf5
# Out:
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# Generating dataset of size 10000
# Saving dataset to 01_training_data/waveform_dataset/waveform_dataset.hdf5

# %% [markdown]
# Load the dataset and visualize an exemplary waveform

# %%
from dingo.gw.dataset.waveform_dataset import WaveformDataset
# Load dataset
waveform_dataset_path = '01_training_data/waveform_dataset/waveform_dataset.hdf5'
wfd = WaveformDataset(file_name=waveform_dataset_path)
print("Each element wfd[i] contains an intrinsic waveform. It is a nested dict with structure")
for k, v in wfd[0].items():
    print("  - " + k)
    if isinstance(v, dict):
        for k1 in v:
            print("    - " + k1)
# Out:
# Loading dataset from 01_training_data/waveform_dataset/waveform_dataset.hdf5.
# Each element wfd[i] contains an intrinsic waveform. It is a nested dict with structure
#   - parameters
#     - a_1
#     - a_2
#     - chirp_mass
#     - geocent_time
#     - luminosity_distance
#     - mass_ratio
#     - phase
#     - phi_jl
#     - theta_jn
#     - tilt_1
#     - tilt_2
#   - waveform
#     - h_cross
#     - h_plus

# %%
# Plot a sample waveform
f_domain = wfd.domain.sample_frequencies
data_sample = wfd[0]['waveform']

plt.plot(f_domain, data_sample['h_cross'].real, c="blue", label=r'$h_{\times}$ real')
plt.plot(f_domain, data_sample['h_cross'].imag, c="cornflowerblue", label=r'$h_{\times}$ imag')
plt.plot(f_domain, data_sample['h_plus'].real, c="tab:red", label=r'$h_+$ real')
plt.plot(f_domain, data_sample['h_plus'].imag, c="coral", label=r'$h_+$ imag')
plt.xlabel(r"Frequency $f$ [Hz]")
plt.ylabel(r"Polarization $h$")
plt.legend();

# %% [markdown]
# ## 2. Generating a noise dataset
# In gravitational wave data analysis, the noise is assumed to be stationary and Gaussian in each frequency bin with the variance given the amplitude spectral density (ASD). Similar to extrinsic parameters, detector noise is repeatedly sampled during training and added to the simulated signal. This augments the training set with new noise realizations for each epoch, reducing overfitting.
# To take into account that the ASD can drift during an observing run, we create an ASD dataset based on stretches of measured noise in the LIGO and Virgo detectors.
# For a detailed explanation about the detector noise, please see the [DINGO documentation](https://dingo-gw.readthedocs.io/en/latest/noise_dataset.html) and paper [Dax+2021](https://arxiv.org/abs/2106.12594).
#
# **Step 1: Prepare settings file**
# To generate the ASD dataset, we need to prepare a settings file which contains the following information within `dataset_settings`:
# - **f_min, f_max** (Optional)
# - **f_s**: Sampling rate. This should be at least twice the value of `f_max` expected to be used.
# - **time_psd**: The entire length of data from which to estimate a power spectral density (PSD, $\mathrm{ASD} = \sqrt{\mathrm{PSD}}$) using Welch's method. Periodigrams are calculated on segments of this, and then averaged using the median method.
# - **T**: The length of each segment on which to take the DFT and calculate a periodigram.
# - **window**: Parameters of the window function used before taking DFT of data segments.
# - **channels** (Optional): Channels where to download the data from. By default will use open data from [GWOSC](https://gwosc.org).
# - **time_gap**: This sets the time that is skipped between consecutive PSD estimates. If set < 0., the time segments overlap.
# - **num_psds_max**: If this is set to 0, all available PSDs will be downloaded. For values > 0, a subset of all available PSDs is used.
# - **detectors**: This list specifies for which detectors we want to download ASDs. Options: H1, L1, V1.
# - **observing_run**: This sets the observing run of the ASDs. Options: O1, O2, O3.
#
# In a DINGO training run where the initial layers of the embedding network are seeded with SVD components, we typically use two ASD datasets: One with a single, fiducial ASD that is fixed during the first training stage, and a second one with all ASDs of the selected observing run. In this tutorial, we will train the network with a single ASD.
#
# More information about the noise modeling with DINGO can be found in the section [Detector Noise](https://dingo-gw.readthedocs.io/en/latest/noise_dataset.html) of the documentation. It also includes examples for `htcondor` settings that allow to run this step on the cluster.

# %%
asd_dataset_settings = """
dataset_settings:
#  f_min: 0         # defaults to 0
#  f_max: 2048      # defaults to f_s/2
  f_s: 4096
  time_psd: 1024
  T: 2.0
  window:
    roll_off: 0.4
    type: tukey
  time_gap: 0 # specifies the time skipped between to consecutive PSD estimates. If set < 0, the time segments overlap
  num_psds_max: 1 # if set > 0, only a subset of all available PSDs will be used
  detectors:
    - H1
    - L1
  observing_run: O1
"""
asd_dataset_settings = yaml.safe_load(asd_dataset_settings)
with open('01_training_data/asd_dataset/asd_dataset_settings.yaml', 'w') as outfile:
    yaml.dump(asd_dataset_settings, outfile, default_flow_style=False)

# %% [markdown]
# **Step 2: Generate ASD dataset**
#
# The following downloads the first valid ASD time segment of the selected observing run (recall `num_psds_max: 1`). For the first observing run O1, this is 1126073529 to 1126074553. It then calculates the ASD using Welch median and saves it to an HDF5 file.

# %%
# !dingo_generate_asd_dataset --settings_file 01_training_data/asd_dataset/asd_dataset_settings.yaml --data_dir 01_training_data/asd_dataset --out_name 01_training_data/asd_dataset/asd_fiducial_O1.hdf5
# Out:
# PyCBC.libutils: pkg-config call failed, setting NO_PKGCONFIG=1
# Downloading strain data and estimating PSDs...
# /home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/pycbc/waveform/plugin.py:99: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Saving dataset to 01_training_data/asd_dataset/tmp/O1/H1/asd_1126073529.hdf5
# Saving dataset to 01_training_data/asd_dataset/tmp/O1/L1/asd_1126072156.hdf5
# Loading dataset from 01_training_data/asd_dataset/tmp/O1/H1/asd_1126073529.hdf5.
# Loading dataset from 01_training_data/asd_dataset/tmp/O1/L1/asd_1126072156.hdf5.
# Merging single dataset files into one...
# Merging 1 datasets into one for detector H1.
# Merging 1 datasets into one for detector L1.
# Saving dataset to 01_training_data/asd_dataset/asd_fiducial_O1.hdf5

# %% [markdown]
# However, we are interested in analyzing the first GW event called GW150914. Therefore, we specify the start and end time of this event in `time_segment.pkl` and provide it as an additional argument to `dingo_generate_asd_dataset`:

# %%
time_GW150914 = 1126259462.391 - 0.0114 # maxlog geocent time of GW150914
asd_start_time = time_GW150914 - asd_dataset_settings["dataset_settings"]["T"]
asd_end_time = time_GW150914
time_segments = {
    'H1': [[asd_start_time, asd_end_time]],
    'L1': [[asd_start_time, asd_end_time]]
}

with open('01_training_data/asd_dataset/time_segment_GW150914.pkl', 'wb') as f:
    pickle.dump(time_segments, f)

# %%
# !dingo_generate_asd_dataset --settings_file 01_training_data/asd_dataset/asd_dataset_settings.yaml --data_dir 01_training_data/asd_dataset --out_name 01_training_data/asd_dataset/asd_GW150914.hdf5 --time_segments_file 01_training_data/asd_dataset/time_segment_GW150914.pkl
# Out:
# PyCBC.libutils: pkg-config call failed, setting NO_PKGCONFIG=1
# Downloading strain data and estimating PSDs...
# Loading dataset from 01_training_data/asd_dataset/tmp/O1/H1/asd_1126259460.3796.hdf5.
# Loading dataset from 01_training_data/asd_dataset/tmp/O1/L1/asd_1126259460.3796.hdf5.
# Merging single dataset files into one...
# Merging 1 datasets into one for detector H1.
# Merging 1 datasets into one for detector L1.
# Saving dataset to 01_training_data/asd_dataset/asd_GW150914.hdf5

# %% [markdown]
# Load and visualize exemplary ASD:

# %%
from dingo.gw.noise.asd_dataset import ASDDataset

# Load ASD dataset
asd_dataset_path = '01_training_data/asd_dataset/asd_GW150914.hdf5'
asds = ASDDataset(file_name=asd_dataset_path, domain_update=wfd.domain.domain_dict)
# Get ASD sample
asd_sample = asds.sample_random_asds()
print("One Datapoint contains:", asd_sample.keys())

plt.loglog(f_domain, asd_sample['H1'], label=r'H1')
plt.loglog(f_domain, asd_sample['L1'], label=r'L1')
plt.xlabel(r"Frequency [Hz]")
plt.ylabel(r"Noise ASD $[1/\sqrt{\mathrm{Hz}}]$")
plt.xlim([wfd.domain.f_min, wfd.domain.f_max])
plt.ylim([1.e-24, 1.e-20])
plt.legend();
# Out:
# Loading dataset from 01_training_data/asd_dataset/asd_GW150914.hdf5.
# One Datapoint contains: dict_keys(['H1', 'L1'])

# %% [markdown]
# ## 3. Training a simple model
# **Step 1: Prepare config file**
#
# The train settings YAML file has several sections:
#
# **(a) data**: Specifies training data.
# - **waveform_dataset_path**: Path to waveform dataset containing intrinsic waveforms
# - **train_fraction**: Fraction of waveform dataset to be used for training. The remainder are used to compute the test loss.
# - **window**: Defines the window function to use when fourier-transforming from time-domain data. It is used here to calculate a window factor for simulating data. See discussion [here](https://dingo-gw.readthedocs.io/en/latest/noise_dataset.html#ref-window-factor).
# - **detectors**: List of detectors that should be used during training. Options: H1, L1, V1. Note: Dingo models are trained for a *fixed set of detectors*. This must be selected prior to training, and a new model must be trained if one wishes to analyze data in a different set of detectors. Thus, e.g., separate models must be trained for HL and HLV configurations.
# - **extrinsic_prior**: Specify the extrinsic prior. Default options are available.
# - **ref_time**: Reference time for the interferometer locations and orientations. See the important note [here](https://dingo-gw.readthedocs.io/en/latest/training_transforms.html#ref-ref-time).
# - **inference_parameters**: Parameters to infer with the model. Must be a subset of `sample["parameters"]`. By specifying a strict subset, this can be used to marginalize over parameters. The default setting points to `dingo.gw.prior.default_inference_parameters`.

# %%
from dingo.gw.prior import default_inference_parameters
default_inference_parameters
# Out:
# ['chirp_mass',
#  'mass_ratio',
#  'phase',
#  'a_1',
#  'a_2',
#  'tilt_1',
#  'tilt_2',
#  'phi_12',
#  'phi_jl',
#  'theta_jn',
#  'luminosity_distance',
#  'geocent_time',
#  'ra',
#  'dec',
#  'psi']

# %% [markdown]
# **(b) model**: Specifies neural model.
# - **posterior_model_type**. Usually `normalizing_flow` (alternative `flow_matching`).
# - **posterior_kwargs**: Specifies the density estimator. For `normalizing_flow` this includes the number of flow steps and kwargs of flow transform `base_transform_kwargs`.
# - **embedding_kwargs**: Specifies embedding network. This is used to compress the data to a latent representation, which is a passed as context to the posterior model. Arguments include, e.g., dimension of output vector `out_dim`, hidden dimensions `hidden_dims`, and how to obtain the SVD components for the initialization of the first layer `svd`.
#
# **(c) training**: Specifies training procedure, optionally divided into stages. Each stage contains:
# - **epochs**: Number of epochs
# - **asd_dataset_path**: Path to the ASD dataset. If the DINGO model is trained in two stages, this should just contain a single fiducial ASD per detector for the first stage and a full ASD dataset per detector for the second stage.
# - **freeze_rb_layer**: Whether to freeze the reduced basis layer in the embedding network in this stage.
# - **optimizer**: Optimizer setings.
# - **scheduler**: Scheduler settings.
# - **batch_size**: Number of data points to use per batch.
#
#
# **(d) local**: Technical settings (no influence on final model).
# - **device**: Which device to train on. Options: `cpu`, `cuda` for training on GPU.
# - **num_workers**: Number of workers that are used to preprocess the data before training. (`num_workers >0` does not work on Mac, see [post](https://stackoverflow.com/questions/64772335/pytorch-w-parallelnative-cpp206))
# - **runtime_limits**: Specifies the maximum time per run and the maximum number of epochs per run.
# - **checkpoint_epochs**: Sets after how many epochs a checkpoint is saved.
#
# For more information on typical values to be used for production, see the tutorials for [training an NPE model](https://dingo-gw.readthedocs.io/en/latest/example_npe_model.html), [training a GNPE model](https://dingo-gw.readthedocs.io/en/latest/example_gnpe_model.html). The documentation contains more details about the [network architecture](https://dingo-gw.readthedocs.io/en/latest/network_architecture.html) as well as the [training procedure](https://dingo-gw.readthedocs.io/en/latest/training.html).
#
# Since we want to infer the posterior masses of GW150914, we fix the extrinsic prior values to the maximum likelihood values of the infered parameters.

# %%
import yaml
train_settings = """
data:
  waveform_dataset_path: 01_training_data/waveform_dataset/waveform_dataset.hdf5  # Contains intrinsic waveforms
  train_fraction: 0.95
  window:  # Needed to calculate window factor for simulated data
    type: tukey
    f_s: 4096
    T: 2.0
    roll_off: 0.4
  detectors:
    - H1
    - L1
  extrinsic_prior:  # Sampled at train time
    dec: bilby.core.prior.analytical.DeltaFunction(-1.2616009712219238)
    ra: bilby.core.prior.analytical.DeltaFunction(1.4557750225067139)
    geocent_time: bilby.core.prior.analytical.DeltaFunction(0.011423417367041111)
    psi: bilby.core.prior.analytical.DeltaFunction(1.2124483585357666)
    luminosity_distance: bilby.core.prior.analytical.DeltaFunction(488.2327880859375)
  ref_time: 1126259462.391
  inference_parameters:
  - chirp_mass
  - mass_ratio

# Model architecture
model:
  # kwargs for neural spline flow
  posterior_model_type: normalizing_flow
  posterior_kwargs:
    num_flow_steps: 5 # 30
    base_transform_kwargs:
      hidden_dim: 64 # 1024
      num_transform_blocks: 5
      activation: elu
      dropout_probability: 0.0
      batch_norm: True
      num_bins: 8
      base_transform_type: rq-coupling
  # kwargs for embedding net
  embedding_kwargs:
    output_dim: 64 # 128
    hidden_dims: [1024, 512, 256, 64]
    activation: elu
    dropout: 0.0
    batch_norm: True
    svd:
      num_training_samples: 1000
      num_validation_samples: 100
      size: 50

# The first stage (and only) stage of training.
training:
  stage_0:
    epochs: 15
    asd_dataset_path: 01_training_data/asd_dataset/asd_GW150914.hdf5
    freeze_rb_layer: True
    optimizer:
      type: adam
      lr: 0.0001
    scheduler:
      type: cosine
      T_max: 15
    batch_size: 512
  # stage_1:
  #   epochs: 5
  #   asd_dataset_path: 01_training_data/asd_dataset/asd_GW150914.hdf5
  #   freeze_rb_layer: False
  #   optimizer:
  #     type: adam
  #     lr: 1.e-5
  #   scheduler:
  #     type: cosine
  #     T_max: 5
  #   batch_size: 64

# Local settings for training that have no impact on the final trained network.
local:
  device: cuda  # [cpu, cuda] Set this to 'cuda' for training on a GPU.
  num_workers: 2  # num_workers >0 does not work on Mac, see https://stackoverflow.com/questions/64772335/pytorch-w-parallelnative-cpp206
  runtime_limits:
    max_time_per_run: 36000
    max_epochs_per_run: 30
  checkpoint_epochs: 15
"""
train_settings = yaml.safe_load(train_settings)
with open('02_training/train_settings.yaml', 'w') as outfile:
    yaml.dump(train_settings, outfile, default_flow_style=False)

# %% [markdown]
# **Step 2: Start training run.**
#
# The following command initiates training. Various pieces of information are output during training, including  SVD performance (e.g., the truncation of the SVD basis and the resulting mismatch), how the new model is initialized, the number of fixed and learnable parameters of the model, the epoch number with training and validation loss, etc.
#
# Training for 15 epochs takes approximately 10 - 15 minutes.

# %%
# !CUDA_VISIBLE_DEVICES="" dingo_train --settings_file 02_training/train_settings.yaml --train_dir 02_training
# Out:
# Beginning new training run.
# Loading dataset from 01_training_data/waveform_dataset/waveform_dataset.hdf5.
# Omitting data keys ['polarizations'].
#
# Building SVD for initialization of embedding network.
# Setting train transforms.
# Omitting
# 	AddWhiteNoiseComplex
# 	RepackageStrainsAndASDS
# 	SelectStandardizeRepackageParameters
# 	UnpackDict
# 	CropMaskStrainRandom
# Loading dataset from 01_training_data/asd_dataset/asd_GW150914.hdf5.
# Calculating new parameter standardizations.
# Generating waveforms for embedding network SVD initialization.
# ...done. This took 0 s.
# Generating SVD basis for ifo:
# ...H1 done.
# ...L1 done.
# ...this took 0 s.
# Testing SVD basis matrices.
# ...H1:
# n = 50
#   Mean mismatch = 2.87905573637115e-08
#   Standard deviation = 8.024405317881061e-08
#   Max mismatch = 7.814806153305653e-07
#   Median mismatch = 1.2723559594807199e-08
#   Percentiles:
#     99    -> 1.9680972707658863e-07
#     99.9  -> 7.230135265051736e-07
#     99.99 -> 7.756339064480161e-07
# Saving dataset to 02_training/svd_H1.hdf5
# ...L1:
# n = 50
#   Mean mismatch = 3.0388270554349005e-08
#   Standard deviation = 6.996655988560496e-08
#   Max mismatch = 6.615379815055888e-07
#   Median mismatch = 1.3787847030766187e-08
#   Percentiles:
#     99    -> 1.7851751429210055e-07
#     99.9  -> 6.132359347842449e-07
#     99.99 -> 6.567077768334462e-07
# Saving dataset to 02_training/svd_L1.hdf5
# Done
# Truncating SVD matrices below index 40.
# ...V matrix shapes:
#       (473, 50)
#       (473, 50)
#
#
# Setting train transforms.
# Loading dataset from 01_training_data/asd_dataset/asd_GW150914.hdf5.
# Calculating new parameter standardizations.
#
# Initializing new posterior model.
# Complete settings:
# dataset_settings:
#   compression: None
#   domain:
#     delta_f: 0.5
#     f_max: 256.0
#     f_min: 20.0
#     type: UniformFrequencyDomain
#   intrinsic_prior:
#     a_1: 0.925635814666748
#     a_2: 0.5538952350616455
#     chirp_mass: bilby.gw.prior.UniformInComponentsChirpMass(minimum=15.0, maximum=50.0)
#     geocent_time: 0.0
#     luminosity_distance: 100.0
#     mass_ratio: bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0)
#     phase: 0.9604566579018894
#     phi_jl: 5.561878204345703
#     theta_jn: 2.624497413635254
#     tilt_1: 2.0111560821533203
#     tilt_2: 1.0743615627288818
#   num_samples: 10000
#   waveform_generator:
#     approximant: IMRPhenomPv2
#     f_ref: 20.0
#     spin_conversion_phase: 0.0
# train_settings:
#   data:
#     detectors:
#     - H1
#     - L1
#     extrinsic_prior:
#       dec: bilby.core.prior.analytical.DeltaFunction(-1.2616009712219238)
#       geocent_time: bilby.core.prior.analytical.DeltaFunction(0.011423417367041111)
#       luminosity_distance: bilby.core.prior.analytical.DeltaFunction(488.2327880859375)
#       psi: bilby.core.prior.analytical.DeltaFunction(1.2124483585357666)
#       ra: bilby.core.prior.analytical.DeltaFunction(1.4557750225067139)
#     inference_parameters:
#     - chirp_mass
#     - mass_ratio
#     ref_time: 1126259462.391
#     train_fraction: 0.95
#     waveform_dataset_path: 01_training_data/waveform_dataset/waveform_dataset.hdf5
#     window:
#       T: 2.0
#       f_s: 4096
#       roll_off: 0.4
#       type: tukey
#     context_parameters: []
#     standardization:
#       mean:
#         chirp_mass: 35.667083740234375
#         mass_ratio: 0.41454192996025085
#       std:
#         chirp_mass: 9.601449012756348
#         mass_ratio: 0.2432817667722702
#   model:
#     embedding_kwargs:
#       activation: elu
#       batch_norm: true
#       dropout: 0.0
#       hidden_dims:
#       - 1024
#       - 512
#       - 256
#       - 64
#       output_dim: 64
#       svd:
#         num_training_samples: 1000
#         num_validation_samples: 100
#         size: 50
#       input_dims:
#       - 2
#       - 3
#       - 473
#       added_context: false
#     posterior_kwargs:
#       base_transform_kwargs:
#         activation: elu
#         base_transform_type: rq-coupling
#         batch_norm: true
#         dropout_probability: 0.0
#         hidden_dim: 64
#         num_bins: 8
#         num_transform_blocks: 5
#       num_flow_steps: 5
#       input_dim: 2
#       context_dim: 64
#     posterior_model_type: normalizing_flow
#   training:
#     stage_0:
#       asd_dataset_path: 01_training_data/asd_dataset/asd_GW150914.hdf5
#       batch_size: 512
#       epochs: 15
#       freeze_rb_layer: true
#       optimizer:
#         lr: 0.0001
#         type: adam
#       scheduler:
#         T_max: 15
#         type: cosine
#
# Putting posterior model to device cpu.
#
# Beginning training stage 0. Settings:
# asd_dataset_path: 01_training_data/asd_dataset/asd_GW150914.hdf5
# batch_size: 512
# epochs: 15
# freeze_rb_layer: true
# optimizer:
#   lr: 0.0001
#   type: adam
# scheduler:
#   T_max: 15
#   type: cosine
#
# Setting train transforms.
# Loading dataset from 01_training_data/asd_dataset/asd_GW150914.hdf5.
# Using previously-calculated parameter standardizations.
# Initializing new optimizer and scheduler.
# Fixed parameters: 284000
# Learnable parameters: 4001431
#
#
# Start training epoch 1 with lr [0.0001]
# /home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Train Epoch: 1 [0/9500 (0%)]		Loss: 2.951 (2.951)		Time Dataloader: 0.088 (0.088)		Time Network: 0.140 (0.140)
# Train Epoch: 1 [512/9500 (5%)]		Loss: 2.901 (2.926)		Time Dataloader: 0.002 (0.045)		Time Network: 0.079 (0.109)
# Train Epoch: 1 [1024/9500 (11%)]		Loss: 2.919 (2.923)		Time Dataloader: 0.003 (0.031)		Time Network: 0.074 (0.098)
# Train Epoch: 1 [1536/9500 (16%)]		Loss: 2.962 (2.933)		Time Dataloader: 0.002 (0.024)		Time Network: 0.077 (0.092)
# Train Epoch: 1 [2048/9500 (22%)]		Loss: 2.979 (2.942)		Time Dataloader: 0.002 (0.019)		Time Network: 0.080 (0.090)
# Train Epoch: 1 [2560/9500 (27%)]		Loss: 2.898 (2.935)		Time Dataloader: 0.002 (0.016)		Time Network: 0.073 (0.087)
# Train Epoch: 1 [3072/9500 (32%)]		Loss: 2.991 (2.943)		Time Dataloader: 0.003 (0.014)		Time Network: 0.078 (0.086)
# Train Epoch: 1 [3584/9500 (38%)]		Loss: 2.910 (2.939)		Time Dataloader: 0.002 (0.013)		Time Network: 0.077 (0.085)
# Train Epoch: 1 [4096/9500 (43%)]		Loss: 2.913 (2.936)		Time Dataloader: 0.003 (0.012)		Time Network: 0.076 (0.084)
# Train Epoch: 1 [4608/9500 (49%)]		Loss: 2.846 (2.927)		Time Dataloader: 0.003 (0.011)		Time Network: 0.080 (0.083)
# Train Epoch: 1 [5120/9500 (54%)]		Loss: 2.822 (2.918)		Time Dataloader: 0.003 (0.010)		Time Network: 0.081 (0.083)
# Train Epoch: 1 [5632/9500 (59%)]		Loss: 2.846 (2.912)		Time Dataloader: 0.003 (0.010)		Time Network: 0.080 (0.083)
# Train Epoch: 1 [6144/9500 (65%)]		Loss: 2.813 (2.904)		Time Dataloader: 0.002 (0.009)		Time Network: 0.070 (0.082)
# Train Epoch: 1 [6656/9500 (70%)]		Loss: 2.818 (2.898)		Time Dataloader: 0.002 (0.008)		Time Network: 0.085 (0.082)
# Train Epoch: 1 [7168/9500 (75%)]		Loss: 2.816 (2.892)		Time Dataloader: 0.003 (0.008)		Time Network: 0.075 (0.082)
# Train Epoch: 1 [7680/9500 (81%)]		Loss: 2.841 (2.889)		Time Dataloader: 0.002 (0.008)		Time Network: 0.073 (0.081)
# Train Epoch: 1 [8192/9500 (86%)]		Loss: 2.776 (2.882)		Time Dataloader: 0.002 (0.007)		Time Network: 0.080 (0.081)
# Train Epoch: 1 [8704/9500 (92%)]		Loss: 2.825 (2.879)		Time Dataloader: 0.002 (0.007)		Time Network: 0.072 (0.080)
# Train Epoch: 1 [9216/9500 (97%)]		Loss: 2.861 (2.879)		Time Dataloader: 0.002 (0.007)		Time Network: 0.054 (0.079)
# Done. This took  0: 2 min.
# Start testing epoch 1
# Test Epoch: 1 [0/500 (0%)]		Loss: 2.803 (2.803)		Time Dataloader: 0.079 (0.079)		Time Network: 0.046 (0.046)
# Done. This took  0: 0 min.
# Saving model to 02_training/model_latest.pt. Done.
# Finished training epoch 1.
#
#
# Start training epoch 2 with lr [9.890738003669029e-05]
# Train Epoch: 2 [0/9500 (0%)]		Loss: 2.835 (2.835)		Time Dataloader: 0.091 (0.091)		Time Network: 0.209 (0.209)
# Train Epoch: 2 [512/9500 (5%)]		Loss: 2.754 (2.795)		Time Dataloader: 0.003 (0.047)		Time Network: 0.111 (0.160)
# Train Epoch: 2 [1024/9500 (11%)]		Loss: 2.837 (2.809)		Time Dataloader: 0.004 (0.032)		Time Network: 0.078 (0.133)
# Train Epoch: 2 [1536/9500 (16%)]		Loss: 2.795 (2.805)		Time Dataloader: 0.001 (0.024)		Time Network: 0.073 (0.118)
# Train Epoch: 2 [2048/9500 (22%)]		Loss: 2.794 (2.803)		Time Dataloader: 0.002 (0.020)		Time Network: 0.072 (0.109)
# Train Epoch: 2 [2560/9500 (27%)]		Loss: 2.743 (2.793)		Time Dataloader: 0.003 (0.017)		Time Network: 0.080 (0.104)
# Train Epoch: 2 [3072/9500 (32%)]		Loss: 2.860 (2.803)		Time Dataloader: 0.002 (0.015)		Time Network: 0.077 (0.100)
# Train Epoch: 2 [3584/9500 (38%)]		Loss: 2.828 (2.806)		Time Dataloader: 0.002 (0.013)		Time Network: 0.087 (0.098)
# Train Epoch: 2 [4096/9500 (43%)]		Loss: 2.790 (2.804)		Time Dataloader: 0.003 (0.012)		Time Network: 0.071 (0.095)
# Train Epoch: 2 [4608/9500 (49%)]		Loss: 2.731 (2.797)		Time Dataloader: 0.002 (0.011)		Time Network: 0.078 (0.094)
# Train Epoch: 2 [5120/9500 (54%)]		Loss: 2.770 (2.794)		Time Dataloader: 0.003 (0.010)		Time Network: 0.074 (0.092)
# Train Epoch: 2 [5632/9500 (59%)]		Loss: 2.732 (2.789)		Time Dataloader: 0.003 (0.010)		Time Network: 0.075 (0.090)
# Train Epoch: 2 [6144/9500 (65%)]		Loss: 2.664 (2.779)		Time Dataloader: 0.002 (0.009)		Time Network: 0.080 (0.090)
# Train Epoch: 2 [6656/9500 (70%)]		Loss: 2.748 (2.777)		Time Dataloader: 0.003 (0.009)		Time Network: 0.079 (0.089)
# Train Epoch: 2 [7168/9500 (75%)]		Loss: 2.733 (2.774)		Time Dataloader: 0.003 (0.008)		Time Network: 0.085 (0.089)
# Train Epoch: 2 [7680/9500 (81%)]		Loss: 2.678 (2.768)		Time Dataloader: 0.002 (0.008)		Time Network: 0.064 (0.087)
# Train Epoch: 2 [8192/9500 (86%)]		Loss: 2.814 (2.771)		Time Dataloader: 0.003 (0.008)		Time Network: 0.080 (0.087)
# Train Epoch: 2 [8704/9500 (92%)]		Loss: 2.754 (2.770)		Time Dataloader: 0.003 (0.007)		Time Network: 0.073 (0.086)
# Train Epoch: 2 [9216/9500 (97%)]		Loss: 2.781 (2.770)		Time Dataloader: 0.002 (0.007)		Time Network: 0.060 (0.084)
# Done. This took  0: 2 min.
# Start testing epoch 2
# Test Epoch: 2 [0/500 (0%)]		Loss: 2.659 (2.659)		Time Dataloader: 0.080 (0.080)		Time Network: 0.048 (0.048)
# Done. This took  0: 0 min.
# Saving model to 02_training/model_latest.pt. Done.
# Finished training epoch 2.
#
#
# Start training epoch 3 with lr [9.567727288213005e-05]
# Train Epoch: 3 [0/9500 (0%)]		Loss: 2.682 (2.682)		Time Dataloader: 0.092 (0.092)		Time Network: 0.197 (0.197)
# Train Epoch: 3 [512/9500 (5%)]		Loss: 2.636 (2.659)		Time Dataloader: 0.002 (0.047)		Time Network: 0.072 (0.134)
# Train Epoch: 3 [1024/9500 (11%)]		Loss: 2.692 (2.670)		Time Dataloader: 0.002 (0.032)		Time Network: 0.075 (0.115)
# Train Epoch: 3 [1536/9500 (16%)]		Loss: 2.714 (2.681)		Time Dataloader: 0.002 (0.025)		Time Network: 0.074 (0.104)
# Train Epoch: 3 [2048/9500 (22%)]		Loss: 2.760 (2.697)		Time Dataloader: 0.003 (0.020)		Time Network: 0.080 (0.100)
# Train Epoch: 3 [2560/9500 (27%)]		Loss: 2.655 (2.690)		Time Dataloader: 0.003 (0.017)		Time Network: 0.081 (0.096)
# Train Epoch: 3 [3072/9500 (32%)]		Loss: 2.693 (2.690)		Time Dataloader: 0.002 (0.015)		Time Network: 0.086 (0.095)
# Train Epoch: 3 [3584/9500 (38%)]		Loss: 2.655 (2.686)		Time Dataloader: 0.002 (0.014)		Time Network: 0.081 (0.093)
# Train Epoch: 3 [4096/9500 (43%)]		Loss: 2.670 (2.684)		Time Dataloader: 0.002 (0.012)		Time Network: 0.086 (0.092)
# Train Epoch: 3 [4608/9500 (49%)]		Loss: 2.699 (2.686)		Time Dataloader: 0.003 (0.011)		Time Network: 0.075 (0.091)
# Train Epoch: 3 [5120/9500 (54%)]		Loss: 2.707 (2.688)		Time Dataloader: 0.002 (0.011)		Time Network: 0.079 (0.090)
# Train Epoch: 3 [5632/9500 (59%)]		Loss: 2.627 (2.682)		Time Dataloader: 0.003 (0.010)		Time Network: 0.070 (0.088)
# Train Epoch: 3 [6144/9500 (65%)]		Loss: 2.642 (2.679)		Time Dataloader: 0.002 (0.009)		Time Network: 0.077 (0.087)
# Train Epoch: 3 [6656/9500 (70%)]		Loss: 2.593 (2.673)		Time Dataloader: 0.002 (0.009)		Time Network: 0.076 (0.086)
# Train Epoch: 3 [7168/9500 (75%)]		Loss: 2.621 (2.670)		Time Dataloader: 0.003 (0.008)		Time Network: 0.075 (0.085)
# Train Epoch: 3 [7680/9500 (81%)]		Loss: 2.632 (2.667)		Time Dataloader: 0.003 (0.008)		Time Network: 0.085 (0.085)
# Train Epoch: 3 [8192/9500 (86%)]		Loss: 2.675 (2.668)		Time Dataloader: 0.002 (0.008)		Time Network: 0.075 (0.085)
# Train Epoch: 3 [8704/9500 (92%)]		Loss: 2.560 (2.662)		Time Dataloader: 0.002 (0.007)		Time Network: 0.084 (0.085)
# Train Epoch: 3 [9216/9500 (97%)]		Loss: 2.572 (2.659)		Time Dataloader: 0.002 (0.007)		Time Network: 0.055 (0.083)
# Done. This took  0: 2 min.
# Start testing epoch 3
# Test Epoch: 3 [0/500 (0%)]		Loss: 2.561 (2.561)		Time Dataloader: 0.080 (0.080)		Time Network: 0.047 (0.047)
# Done. This took  0: 0 min.
# Saving model to 02_training/model_latest.pt. Done.
# Finished training epoch 3.
#
#
# Start training epoch 4 with lr [9.045084971874738e-05]
# Train Epoch: 4 [0/9500 (0%)]		Loss: 2.627 (2.627)		Time Dataloader: 0.086 (0.086)		Time Network: 0.201 (0.201)
# Train Epoch: 4 [512/9500 (5%)]		Loss: 2.630 (2.628)		Time Dataloader: 0.003 (0.044)		Time Network: 0.079 (0.140)
# Train Epoch: 4 [1024/9500 (11%)]		Loss: 2.580 (2.612)		Time Dataloader: 0.002 (0.030)		Time Network: 0.078 (0.119)
# Train Epoch: 4 [1536/9500 (16%)]		Loss: 2.491 (2.582)		Time Dataloader: 0.003 (0.023)		Time Network: 0.075 (0.108)
# Train Epoch: 4 [2048/9500 (22%)]		Loss: 2.689 (2.603)		Time Dataloader: 0.003 (0.019)		Time Network: 0.075 (0.102)
# Train Epoch: 4 [2560/9500 (27%)]		Loss: 2.595 (2.602)		Time Dataloader: 0.003 (0.017)		Time Network: 0.082 (0.098)
# Train Epoch: 4 [3072/9500 (32%)]		Loss: 2.508 (2.588)		Time Dataloader: 0.002 (0.014)		Time Network: 0.073 (0.095)
# Train Epoch: 4 [3584/9500 (38%)]		Loss: 2.525 (2.580)		Time Dataloader: 0.003 (0.013)		Time Network: 0.070 (0.092)
# Train Epoch: 4 [4096/9500 (43%)]		Loss: 2.534 (2.575)		Time Dataloader: 0.003 (0.012)		Time Network: 0.080 (0.090)
# Train Epoch: 4 [4608/9500 (49%)]		Loss: 2.549 (2.573)		Time Dataloader: 0.002 (0.011)		Time Network: 0.078 (0.089)
# Train Epoch: 4 [5120/9500 (54%)]		Loss: 2.630 (2.578)		Time Dataloader: 0.002 (0.010)		Time Network: 0.071 (0.088)
# Train Epoch: 4 [5632/9500 (59%)]		Loss: 2.526 (2.574)		Time Dataloader: 0.003 (0.009)		Time Network: 0.079 (0.087)
# Train Epoch: 4 [6144/9500 (65%)]		Loss: 2.555 (2.572)		Time Dataloader: 0.003 (0.009)		Time Network: 0.082 (0.086)
# Train Epoch: 4 [6656/9500 (70%)]		Loss: 2.512 (2.568)		Time Dataloader: 0.002 (0.008)		Time Network: 0.089 (0.087)
# Train Epoch: 4 [7168/9500 (75%)]		Loss: 2.514 (2.564)		Time Dataloader: 0.003 (0.008)		Time Network: 0.069 (0.085)
# Train Epoch: 4 [7680/9500 (81%)]		Loss: 2.496 (2.560)		Time Dataloader: 0.003 (0.008)		Time Network: 0.068 (0.084)
# Train Epoch: 4 [8192/9500 (86%)]		Loss: 2.453 (2.554)		Time Dataloader: 0.002 (0.007)		Time Network: 0.076 (0.084)
# Train Epoch: 4 [8704/9500 (92%)]		Loss: 2.539 (2.553)		Time Dataloader: 0.003 (0.007)		Time Network: 0.072 (0.083)
# Train Epoch: 4 [9216/9500 (97%)]		Loss: 2.460 (2.550)		Time Dataloader: 0.002 (0.007)		Time Network: 0.050 (0.081)
# Done. This took  0: 2 min.
# Start testing epoch 4
# Test Epoch: 4 [0/500 (0%)]		Loss: 2.417 (2.417)		Time Dataloader: 0.082 (0.082)		Time Network: 0.050 (0.050)
# Done. This took  0: 0 min.
# Saving model to 02_training/model_latest.pt. Done.
# Finished training epoch 4.
#
#
# Start training epoch 5 with lr [8.345653031794292e-05]
# Train Epoch: 5 [0/9500 (0%)]		Loss: 2.487 (2.487)		Time Dataloader: 0.091 (0.091)		Time Network: 0.189 (0.189)
# Train Epoch: 5 [512/9500 (5%)]		Loss: 2.503 (2.495)		Time Dataloader: 0.002 (0.047)		Time Network: 0.077 (0.133)
# Train Epoch: 5 [1024/9500 (11%)]		Loss: 2.395 (2.462)		Time Dataloader: 0.002 (0.032)		Time Network: 0.079 (0.115)
# Train Epoch: 5 [1536/9500 (16%)]		Loss: 2.448 (2.458)		Time Dataloader: 0.003 (0.025)		Time Network: 0.078 (0.106)
# Train Epoch: 5 [2048/9500 (22%)]		Loss: 2.484 (2.463)		Time Dataloader: 0.002 (0.020)		Time Network: 0.072 (0.099)
# Train Epoch: 5 [2560/9500 (27%)]		Loss: 2.473 (2.465)		Time Dataloader: 0.003 (0.017)		Time Network: 0.072 (0.094)
# Train Epoch: 5 [3072/9500 (32%)]		Loss: 2.438 (2.461)		Time Dataloader: 0.002 (0.015)		Time Network: 0.071 (0.091)
# Train Epoch: 5 [3584/9500 (38%)]		Loss: 2.451 (2.460)		Time Dataloader: 0.002 (0.013)		Time Network: 0.083 (0.090)
# Train Epoch: 5 [4096/9500 (43%)]		Loss: 2.360 (2.449)		Time Dataloader: 0.002 (0.012)		Time Network: 0.085 (0.090)
# Train Epoch: 5 [4608/9500 (49%)]		Loss: 2.505 (2.454)		Time Dataloader: 0.003 (0.011)		Time Network: 0.082 (0.089)
# Train Epoch: 5 [5120/9500 (54%)]		Loss: 2.404 (2.450)		Time Dataloader: 0.002 (0.010)		Time Network: 0.080 (0.088)
# Train Epoch: 5 [5632/9500 (59%)]		Loss: 2.403 (2.446)		Time Dataloader: 0.002 (0.010)		Time Network: 0.079 (0.087)
# Train Epoch: 5 [6144/9500 (65%)]		Loss: 2.467 (2.448)		Time Dataloader: 0.003 (0.009)		Time Network: 0.076 (0.086)
# Train Epoch: 5 [6656/9500 (70%)]		Loss: 2.391 (2.443)		Time Dataloader: 0.002 (0.009)		Time Network: 0.076 (0.086)
# Train Epoch: 5 [7168/9500 (75%)]		Loss: 2.359 (2.438)		Time Dataloader: 0.003 (0.008)		Time Network: 0.119 (0.088)
# Train Epoch: 5 [7680/9500 (81%)]		Loss: 2.418 (2.437)		Time Dataloader: 0.003 (0.008)		Time Network: 0.071 (0.087)
# Train Epoch: 5 [8192/9500 (86%)]		Loss: 2.406 (2.435)		Time Dataloader: 0.002 (0.008)		Time Network: 0.075 (0.086)
# Train Epoch: 5 [8704/9500 (92%)]		Loss: 2.320 (2.428)		Time Dataloader: 0.002 (0.007)		Time Network: 0.087 (0.086)
# Train Epoch: 5 [9216/9500 (97%)]		Loss: 2.362 (2.426)		Time Dataloader: 0.002 (0.007)		Time Network: 0.059 (0.085)
# Done. This took  0: 2 min.
# Start testing epoch 5
# Test Epoch: 5 [0/500 (0%)]		Loss: 2.273 (2.273)		Time Dataloader: 0.085 (0.085)		Time Network: 0.050 (0.050)
# Done. This took  0: 0 min.
# Saving model to 02_training/model_latest.pt. Done.
# Finished training epoch 5.
#
#
# Start training epoch 6 with lr [7.500000000000001e-05]
# Train Epoch: 6 [0/9500 (0%)]		Loss: 2.392 (2.392)		Time Dataloader: 0.089 (0.089)		Time Network: 0.190 (0.190)
# Train Epoch: 6 [512/9500 (5%)]		Loss: 2.268 (2.330)		Time Dataloader: 0.003 (0.046)		Time Network: 0.086 (0.138)
# Train Epoch: 6 [1024/9500 (11%)]		Loss: 2.325 (2.328)		Time Dataloader: 0.002 (0.031)		Time Network: 0.077 (0.118)
# Train Epoch: 6 [1536/9500 (16%)]		Loss: 2.373 (2.340)		Time Dataloader: 0.002 (0.024)		Time Network: 0.071 (0.106)
# Train Epoch: 6 [2048/9500 (22%)]		Loss: 2.309 (2.333)		Time Dataloader: 0.002 (0.020)		Time Network: 0.075 (0.100)
# Train Epoch: 6 [2560/9500 (27%)]		Loss: 2.396 (2.344)		Time Dataloader: 0.003 (0.017)		Time Network: 0.074 (0.096)
# Train Epoch: 6 [3072/9500 (32%)]		Loss: 2.327 (2.341)		Time Dataloader: 0.003 (0.015)		Time Network: 0.080 (0.093)
# Train Epoch: 6 [3584/9500 (38%)]		Loss: 2.307 (2.337)		Time Dataloader: 0.003 (0.013)		Time Network: 0.075 (0.091)
# Train Epoch: 6 [4096/9500 (43%)]		Loss: 2.318 (2.335)		Time Dataloader: 0.003 (0.012)		Time Network: 0.077 (0.090)
# Train Epoch: 6 [4608/9500 (49%)]		Loss: 2.401 (2.342)		Time Dataloader: 0.002 (0.011)		Time Network: 0.072 (0.088)
# Train Epoch: 6 [5120/9500 (54%)]		Loss: 2.292 (2.337)		Time Dataloader: 0.002 (0.010)		Time Network: 0.081 (0.087)
# Train Epoch: 6 [5632/9500 (59%)]		Loss: 2.312 (2.335)		Time Dataloader: 0.003 (0.010)		Time Network: 0.075 (0.086)
# Train Epoch: 6 [6144/9500 (65%)]		Loss: 2.273 (2.330)		Time Dataloader: 0.003 (0.009)		Time Network: 0.081 (0.086)
# Train Epoch: 6 [6656/9500 (70%)]		Loss: 2.298 (2.328)		Time Dataloader: 0.003 (0.009)		Time Network: 0.077 (0.085)
# Train Epoch: 6 [7168/9500 (75%)]		Loss: 2.258 (2.323)		Time Dataloader: 0.002 (0.008)		Time Network: 0.074 (0.084)
# Train Epoch: 6 [7680/9500 (81%)]		Loss: 2.352 (2.325)		Time Dataloader: 0.002 (0.008)		Time Network: 0.072 (0.084)
# Train Epoch: 6 [8192/9500 (86%)]		Loss: 2.244 (2.320)		Time Dataloader: 0.003 (0.008)		Time Network: 0.068 (0.083)
# Train Epoch: 6 [8704/9500 (92%)]		Loss: 2.201 (2.314)		Time Dataloader: 0.003 (0.007)		Time Network: 0.085 (0.083)
# Train Epoch: 6 [9216/9500 (97%)]		Loss: 2.313 (2.314)		Time Dataloader: 0.002 (0.007)		Time Network: 0.055 (0.081)
# Done. This took  0: 2 min.
# Start testing epoch 6
# Test Epoch: 6 [0/500 (0%)]		Loss: 2.176 (2.176)		Time Dataloader: 0.084 (0.084)		Time Network: 0.051 (0.051)
# Done. This took  0: 0 min.
# Saving model to 02_training/model_latest.pt. Done.
# Finished training epoch 6.
#
#
# Start training epoch 7 with lr [6.545084971874738e-05]
# Train Epoch: 7 [0/9500 (0%)]		Loss: 2.353 (2.353)		Time Dataloader: 0.092 (0.092)		Time Network: 0.189 (0.189)
# Train Epoch: 7 [512/9500 (5%)]		Loss: 2.128 (2.241)		Time Dataloader: 0.002 (0.047)		Time Network: 0.084 (0.136)
# Train Epoch: 7 [1024/9500 (11%)]		Loss: 2.189 (2.223)		Time Dataloader: 0.004 (0.033)		Time Network: 0.081 (0.118)
# Train Epoch: 7 [1536/9500 (16%)]		Loss: 2.236 (2.227)		Time Dataloader: 0.001 (0.025)		Time Network: 0.079 (0.108)
# Train Epoch: 7 [2048/9500 (22%)]		Loss: 2.210 (2.223)		Time Dataloader: 0.003 (0.020)		Time Network: 0.076 (0.102)
# Train Epoch: 7 [2560/9500 (27%)]		Loss: 2.253 (2.228)		Time Dataloader: 0.003 (0.017)		Time Network: 0.075 (0.097)
# Train Epoch: 7 [3072/9500 (32%)]		Loss: 2.213 (2.226)		Time Dataloader: 0.003 (0.015)		Time Network: 0.077 (0.094)
# Train Epoch: 7 [3584/9500 (38%)]		Loss: 2.259 (2.230)		Time Dataloader: 0.003 (0.014)		Time Network: 0.073 (0.092)
# Train Epoch: 7 [4096/9500 (43%)]		Loss: 2.173 (2.224)		Time Dataloader: 0.003 (0.013)		Time Network: 0.079 (0.090)
# Train Epoch: 7 [4608/9500 (49%)]		Loss: 2.158 (2.217)		Time Dataloader: 0.002 (0.012)		Time Network: 0.072 (0.088)
# Train Epoch: 7 [5120/9500 (54%)]		Loss: 2.167 (2.213)		Time Dataloader: 0.003 (0.011)		Time Network: 0.081 (0.088)
# Train Epoch: 7 [5632/9500 (59%)]		Loss: 2.159 (2.208)		Time Dataloader: 0.002 (0.010)		Time Network: 0.075 (0.087)
# Train Epoch: 7 [6144/9500 (65%)]		Loss: 2.275 (2.213)		Time Dataloader: 0.003 (0.009)		Time Network: 0.083 (0.086)
# Train Epoch: 7 [6656/9500 (70%)]		Loss: 2.230 (2.215)		Time Dataloader: 0.003 (0.009)		Time Network: 0.076 (0.086)
# Train Epoch: 7 [7168/9500 (75%)]		Loss: 2.193 (2.213)		Time Dataloader: 0.003 (0.009)		Time Network: 0.071 (0.085)
# Train Epoch: 7 [7680/9500 (81%)]		Loss: 2.188 (2.212)		Time Dataloader: 0.002 (0.008)		Time Network: 0.064 (0.083)
# Train Epoch: 7 [8192/9500 (86%)]		Loss: 2.196 (2.211)		Time Dataloader: 0.002 (0.008)		Time Network: 0.071 (0.083)
# Train Epoch: 7 [8704/9500 (92%)]		Loss: 2.106 (2.205)		Time Dataloader: 0.002 (0.008)		Time Network: 0.075 (0.082)
# Train Epoch: 7 [9216/9500 (97%)]		Loss: 2.247 (2.206)		Time Dataloader: 0.002 (0.007)		Time Network: 0.050 (0.081)
# Done. This took  0: 2 min.
# Start testing epoch 7
# Test Epoch: 7 [0/500 (0%)]		Loss: 2.044 (2.044)		Time Dataloader: 0.085 (0.085)		Time Network: 0.048 (0.048)
# Done. This took  0: 0 min.
# Saving model to 02_training/model_latest.pt. Done.
# Finished training epoch 7.
#
#
# Start training epoch 8 with lr [5.522642316338269e-05]
# Train Epoch: 8 [0/9500 (0%)]		Loss: 2.152 (2.152)		Time Dataloader: 0.123 (0.123)		Time Network: 0.213 (0.213)
# Train Epoch: 8 [512/9500 (5%)]		Loss: 2.089 (2.121)		Time Dataloader: 0.003 (0.063)		Time Network: 0.079 (0.146)
# Train Epoch: 8 [1024/9500 (11%)]		Loss: 2.216 (2.152)		Time Dataloader: 0.003 (0.043)		Time Network: 0.078 (0.123)
# Train Epoch: 8 [1536/9500 (16%)]		Loss: 2.198 (2.164)		Time Dataloader: 0.003 (0.033)		Time Network: 0.074 (0.111)
# Train Epoch: 8 [2048/9500 (22%)]		Loss: 2.138 (2.159)		Time Dataloader: 0.002 (0.027)		Time Network: 0.080 (0.105)
# Train Epoch: 8 [2560/9500 (27%)]		Loss: 2.088 (2.147)		Time Dataloader: 0.003 (0.023)		Time Network: 0.079 (0.101)
# Train Epoch: 8 [3072/9500 (32%)]		Loss: 2.132 (2.145)		Time Dataloader: 0.002 (0.020)		Time Network: 0.084 (0.098)
# Train Epoch: 8 [3584/9500 (38%)]		Loss: 2.125 (2.142)		Time Dataloader: 0.002 (0.018)		Time Network: 0.073 (0.095)
# Train Epoch: 8 [4096/9500 (43%)]		Loss: 2.125 (2.140)		Time Dataloader: 0.002 (0.016)		Time Network: 0.077 (0.093)
# Train Epoch: 8 [4608/9500 (49%)]		Loss: 2.079 (2.134)		Time Dataloader: 0.003 (0.014)		Time Network: 0.080 (0.092)
# Train Epoch: 8 [5120/9500 (54%)]		Loss: 2.109 (2.132)		Time Dataloader: 0.003 (0.013)		Time Network: 0.078 (0.090)
# Train Epoch: 8 [5632/9500 (59%)]		Loss: 2.129 (2.132)		Time Dataloader: 0.003 (0.013)		Time Network: 0.086 (0.090)
# Train Epoch: 8 [6144/9500 (65%)]		Loss: 2.151 (2.133)		Time Dataloader: 0.002 (0.012)		Time Network: 0.074 (0.089)
# Train Epoch: 8 [6656/9500 (70%)]		Loss: 2.034 (2.126)		Time Dataloader: 0.002 (0.011)		Time Network: 0.077 (0.088)
# Train Epoch: 8 [7168/9500 (75%)]		Loss: 2.244 (2.134)		Time Dataloader: 0.003 (0.011)		Time Network: 0.087 (0.088)
# Train Epoch: 8 [7680/9500 (81%)]		Loss: 2.104 (2.132)		Time Dataloader: 0.002 (0.010)		Time Network: 0.075 (0.087)
# Train Epoch: 8 [8192/9500 (86%)]		Loss: 2.090 (2.129)		Time Dataloader: 0.002 (0.010)		Time Network: 0.078 (0.087)
# Train Epoch: 8 [8704/9500 (92%)]		Loss: 2.027 (2.124)		Time Dataloader: 0.003 (0.009)		Time Network: 0.068 (0.086)
# Train Epoch: 8 [9216/9500 (97%)]		Loss: 2.015 (2.121)		Time Dataloader: 0.002 (0.009)		Time Network: 0.051 (0.084)
# Done. This took  0: 2 min.
# Start testing epoch 8
# Test Epoch: 8 [0/500 (0%)]		Loss: 1.963 (1.963)		Time Dataloader: 0.080 (0.080)		Time Network: 0.045 (0.045)
# Done. This took  0: 0 min.
# Saving model to 02_training/model_latest.pt. Done.
# Finished training epoch 8.
#
#
# Start training epoch 9 with lr [4.4773576836617344e-05]
# Train Epoch: 9 [0/9500 (0%)]		Loss: 2.180 (2.180)		Time Dataloader: 0.090 (0.090)		Time Network: 0.204 (0.204)
# Train Epoch: 9 [512/9500 (5%)]		Loss: 2.098 (2.139)		Time Dataloader: 0.002 (0.046)		Time Network: 0.070 (0.137)
# Train Epoch: 9 [1024/9500 (11%)]		Loss: 2.034 (2.104)		Time Dataloader: 0.002 (0.032)		Time Network: 0.076 (0.117)
# Train Epoch: 9 [1536/9500 (16%)]		Loss: 2.005 (2.079)		Time Dataloader: 0.003 (0.024)		Time Network: 0.083 (0.108)
# Train Epoch: 9 [2048/9500 (22%)]		Loss: 1.999 (2.063)		Time Dataloader: 0.003 (0.020)		Time Network: 0.072 (0.101)
# Train Epoch: 9 [2560/9500 (27%)]		Loss: 2.028 (2.057)		Time Dataloader: 0.002 (0.017)		Time Network: 0.076 (0.097)
# Train Epoch: 9 [3072/9500 (32%)]		Loss: 2.142 (2.069)		Time Dataloader: 0.003 (0.015)		Time Network: 0.084 (0.095)
# Train Epoch: 9 [3584/9500 (38%)]		Loss: 2.064 (2.069)		Time Dataloader: 0.003 (0.013)		Time Network: 0.075 (0.093)
# Train Epoch: 9 [4096/9500 (43%)]		Loss: 2.008 (2.062)		Time Dataloader: 0.002 (0.012)		Time Network: 0.077 (0.091)
# Train Epoch: 9 [4608/9500 (49%)]		Loss: 2.011 (2.057)		Time Dataloader: 0.003 (0.011)		Time Network: 0.084 (0.090)
# Train Epoch: 9 [5120/9500 (54%)]		Loss: 1.971 (2.049)		Time Dataloader: 0.002 (0.010)		Time Network: 0.076 (0.089)
# Train Epoch: 9 [5632/9500 (59%)]		Loss: 2.067 (2.050)		Time Dataloader: 0.002 (0.010)		Time Network: 0.079 (0.088)
# Train Epoch: 9 [6144/9500 (65%)]		Loss: 2.043 (2.050)		Time Dataloader: 0.003 (0.009)		Time Network: 0.074 (0.087)
# Train Epoch: 9 [6656/9500 (70%)]		Loss: 2.077 (2.052)		Time Dataloader: 0.003 (0.009)		Time Network: 0.076 (0.086)
# Train Epoch: 9 [7168/9500 (75%)]		Loss: 2.146 (2.058)		Time Dataloader: 0.003 (0.008)		Time Network: 0.070 (0.085)
# Train Epoch: 9 [7680/9500 (81%)]		Loss: 2.123 (2.062)		Time Dataloader: 0.002 (0.008)		Time Network: 0.070 (0.084)
# Train Epoch: 9 [8192/9500 (86%)]		Loss: 1.781 (2.046)		Time Dataloader: 0.002 (0.008)		Time Network: 0.086 (0.084)
# Train Epoch: 9 [8704/9500 (92%)]		Loss: 2.036 (2.045)		Time Dataloader: 0.002 (0.007)		Time Network: 0.072 (0.084)
# Train Epoch: 9 [9216/9500 (97%)]		Loss: 2.170 (2.049)		Time Dataloader: 0.002 (0.007)		Time Network: 0.056 (0.082)
# Done. This took  0: 2 min.
# Start testing epoch 9
# Test Epoch: 9 [0/500 (0%)]		Loss: 1.887 (1.887)		Time Dataloader: 0.083 (0.083)		Time Network: 0.046 (0.046)
# Done. This took  0: 0 min.
# Saving model to 02_training/model_latest.pt. Done.
# Finished training epoch 9.
#
#
# Start training epoch 10 with lr [3.454915028125264e-05]
# Train Epoch: 10 [0/9500 (0%)]		Loss: 1.935 (1.935)		Time Dataloader: 0.119 (0.119)		Time Network: 0.201 (0.201)
# Train Epoch: 10 [512/9500 (5%)]		Loss: 1.955 (1.945)		Time Dataloader: 0.002 (0.060)		Time Network: 0.086 (0.144)
# Train Epoch: 10 [1024/9500 (11%)]		Loss: 2.059 (1.983)		Time Dataloader: 0.003 (0.041)		Time Network: 0.075 (0.121)
# Train Epoch: 10 [1536/9500 (16%)]		Loss: 2.038 (1.997)		Time Dataloader: 0.003 (0.032)		Time Network: 0.078 (0.110)
# Train Epoch: 10 [2048/9500 (22%)]		Loss: 2.085 (2.014)		Time Dataloader: 0.003 (0.026)		Time Network: 0.084 (0.105)
# Train Epoch: 10 [2560/9500 (27%)]		Loss: 1.936 (2.001)		Time Dataloader: 0.003 (0.022)		Time Network: 0.072 (0.099)
# Train Epoch: 10 [3072/9500 (32%)]		Loss: 1.976 (1.998)		Time Dataloader: 0.002 (0.019)		Time Network: 0.080 (0.097)
# Train Epoch: 10 [3584/9500 (38%)]		Loss: 1.952 (1.992)		Time Dataloader: 0.003 (0.017)		Time Network: 0.082 (0.095)
# Train Epoch: 10 [4096/9500 (43%)]		Loss: 2.038 (1.997)		Time Dataloader: 0.002 (0.015)		Time Network: 0.080 (0.093)
# Train Epoch: 10 [4608/9500 (49%)]		Loss: 2.039 (2.001)		Time Dataloader: 0.002 (0.014)		Time Network: 0.075 (0.091)
# Train Epoch: 10 [5120/9500 (54%)]		Loss: 1.908 (1.993)		Time Dataloader: 0.002 (0.013)		Time Network: 0.082 (0.091)
# Train Epoch: 10 [5632/9500 (59%)]		Loss: 1.960 (1.990)		Time Dataloader: 0.002 (0.012)		Time Network: 0.083 (0.090)
# Train Epoch: 10 [6144/9500 (65%)]		Loss: 1.930 (1.985)		Time Dataloader: 0.002 (0.011)		Time Network: 0.068 (0.088)
# Train Epoch: 10 [6656/9500 (70%)]		Loss: 1.952 (1.983)		Time Dataloader: 0.002 (0.011)		Time Network: 0.078 (0.088)
# Train Epoch: 10 [7168/9500 (75%)]		Loss: 1.931 (1.979)		Time Dataloader: 0.003 (0.010)		Time Network: 0.080 (0.087)
# Train Epoch: 10 [7680/9500 (81%)]		Loss: 1.946 (1.977)		Time Dataloader: 0.003 (0.010)		Time Network: 0.073 (0.086)
# Train Epoch: 10 [8192/9500 (86%)]		Loss: 2.026 (1.980)		Time Dataloader: 0.003 (0.009)		Time Network: 0.067 (0.085)
# Train Epoch: 10 [8704/9500 (92%)]		Loss: 1.931 (1.977)		Time Dataloader: 0.003 (0.009)		Time Network: 0.073 (0.084)
# Train Epoch: 10 [9216/9500 (97%)]		Loss: 2.006 (1.978)		Time Dataloader: 0.002 (0.009)		Time Network: 0.055 (0.083)
# Done. This took  0: 2 min.
# Start testing epoch 10
# Test Epoch: 10 [0/500 (0%)]		Loss: 1.815 (1.815)		Time Dataloader: 0.084 (0.084)		Time Network: 0.050 (0.050)
# Done. This took  0: 0 min.
# Saving model to 02_training/model_latest.pt. Done.
# Finished training epoch 10.
#
#
# Start training epoch 11 with lr [2.5000000000000018e-05]
# Train Epoch: 11 [0/9500 (0%)]		Loss: 1.924 (1.924)		Time Dataloader: 0.094 (0.094)		Time Network: 0.199 (0.199)
# Train Epoch: 11 [512/9500 (5%)]		Loss: 1.943 (1.934)		Time Dataloader: 0.003 (0.048)		Time Network: 0.081 (0.140)
# Train Epoch: 11 [1024/9500 (11%)]		Loss: 1.950 (1.939)		Time Dataloader: 0.002 (0.033)		Time Network: 0.078 (0.120)
# Train Epoch: 11 [1536/9500 (16%)]		Loss: 1.886 (1.926)		Time Dataloader: 0.002 (0.025)		Time Network: 0.073 (0.108)
# Train Epoch: 11 [2048/9500 (22%)]		Loss: 1.907 (1.922)		Time Dataloader: 0.003 (0.021)		Time Network: 0.073 (0.101)
# Train Epoch: 11 [2560/9500 (27%)]		Loss: 1.985 (1.933)		Time Dataloader: 0.002 (0.018)		Time Network: 0.075 (0.096)
# Train Epoch: 11 [3072/9500 (32%)]		Loss: 1.865 (1.923)		Time Dataloader: 0.002 (0.015)		Time Network: 0.081 (0.094)
# Train Epoch: 11 [3584/9500 (38%)]		Loss: 2.050 (1.939)		Time Dataloader: 0.003 (0.014)		Time Network: 0.072 (0.092)
# Train Epoch: 11 [4096/9500 (43%)]		Loss: 1.929 (1.938)		Time Dataloader: 0.003 (0.013)		Time Network: 0.073 (0.089)
# Train Epoch: 11 [4608/9500 (49%)]		Loss: 1.966 (1.941)		Time Dataloader: 0.003 (0.012)		Time Network: 0.076 (0.088)
# Train Epoch: 11 [5120/9500 (54%)]		Loss: 1.963 (1.943)		Time Dataloader: 0.003 (0.011)		Time Network: 0.076 (0.087)
# Train Epoch: 11 [5632/9500 (59%)]		Loss: 1.813 (1.932)		Time Dataloader: 0.002 (0.010)		Time Network: 0.075 (0.086)
# Train Epoch: 11 [6144/9500 (65%)]		Loss: 1.890 (1.929)		Time Dataloader: 0.002 (0.009)		Time Network: 0.076 (0.085)
# Train Epoch: 11 [6656/9500 (70%)]		Loss: 1.816 (1.920)		Time Dataloader: 0.002 (0.009)		Time Network: 0.078 (0.085)
# Train Epoch: 11 [7168/9500 (75%)]		Loss: 1.945 (1.922)		Time Dataloader: 0.003 (0.009)		Time Network: 0.072 (0.084)
# Train Epoch: 11 [7680/9500 (81%)]		Loss: 1.908 (1.921)		Time Dataloader: 0.002 (0.008)		Time Network: 0.098 (0.085)
# Train Epoch: 11 [8192/9500 (86%)]		Loss: 2.075 (1.930)		Time Dataloader: 0.002 (0.008)		Time Network: 0.076 (0.084)
# Train Epoch: 11 [8704/9500 (92%)]		Loss: 1.880 (1.927)		Time Dataloader: 0.002 (0.007)		Time Network: 0.072 (0.084)
# Train Epoch: 11 [9216/9500 (97%)]		Loss: 2.045 (1.931)		Time Dataloader: 0.002 (0.007)		Time Network: 0.058 (0.082)
# Done. This took  0: 2 min.
# Start testing epoch 11
# Test Epoch: 11 [0/500 (0%)]		Loss: 1.782 (1.782)		Time Dataloader: 0.080 (0.080)		Time Network: 0.048 (0.048)
# Done. This took  0: 0 min.
# Saving model to 02_training/model_latest.pt. Done.
# Finished training epoch 11.
#
#
# Start training epoch 12 with lr [1.654346968205711e-05]
# Train Epoch: 12 [0/9500 (0%)]		Loss: 1.863 (1.863)		Time Dataloader: 0.091 (0.091)		Time Network: 0.208 (0.208)
# Train Epoch: 12 [512/9500 (5%)]		Loss: 1.909 (1.886)		Time Dataloader: 0.002 (0.047)		Time Network: 0.082 (0.145)
# Train Epoch: 12 [1024/9500 (11%)]		Loss: 1.871 (1.881)		Time Dataloader: 0.002 (0.032)		Time Network: 0.083 (0.124)
# Train Epoch: 12 [1536/9500 (16%)]		Loss: 1.888 (1.883)		Time Dataloader: 0.003 (0.025)		Time Network: 0.080 (0.113)
# Train Epoch: 12 [2048/9500 (22%)]		Loss: 1.946 (1.895)		Time Dataloader: 0.002 (0.020)		Time Network: 0.071 (0.105)
# Train Epoch: 12 [2560/9500 (27%)]		Loss: 1.816 (1.882)		Time Dataloader: 0.002 (0.017)		Time Network: 0.083 (0.101)
# Train Epoch: 12 [3072/9500 (32%)]		Loss: 1.846 (1.877)		Time Dataloader: 0.003 (0.015)		Time Network: 0.084 (0.099)
# Train Epoch: 12 [3584/9500 (38%)]		Loss: 1.952 (1.886)		Time Dataloader: 0.002 (0.014)		Time Network: 0.077 (0.096)
# Train Epoch: 12 [4096/9500 (43%)]		Loss: 1.885 (1.886)		Time Dataloader: 0.002 (0.012)		Time Network: 0.076 (0.094)
# Train Epoch: 12 [4608/9500 (49%)]		Loss: 2.008 (1.898)		Time Dataloader: 0.003 (0.011)		Time Network: 0.077 (0.092)
# Train Epoch: 12 [5120/9500 (54%)]		Loss: 1.977 (1.905)		Time Dataloader: 0.003 (0.011)		Time Network: 0.076 (0.091)
# Train Epoch: 12 [5632/9500 (59%)]		Loss: 1.959 (1.910)		Time Dataloader: 0.003 (0.010)		Time Network: 0.085 (0.090)
# Train Epoch: 12 [6144/9500 (65%)]		Loss: 1.743 (1.897)		Time Dataloader: 0.002 (0.009)		Time Network: 0.081 (0.089)
# Train Epoch: 12 [6656/9500 (70%)]		Loss: 1.959 (1.902)		Time Dataloader: 0.002 (0.009)		Time Network: 0.094 (0.090)
# Train Epoch: 12 [7168/9500 (75%)]		Loss: 1.905 (1.902)		Time Dataloader: 0.003 (0.008)		Time Network: 0.072 (0.089)
# Train Epoch: 12 [7680/9500 (81%)]		Loss: 1.730 (1.891)		Time Dataloader: 0.003 (0.008)		Time Network: 0.071 (0.088)
# Train Epoch: 12 [8192/9500 (86%)]		Loss: 2.131 (1.905)		Time Dataloader: 0.003 (0.008)		Time Network: 0.078 (0.087)
# Train Epoch: 12 [8704/9500 (92%)]		Loss: 1.853 (1.902)		Time Dataloader: 0.002 (0.007)		Time Network: 0.074 (0.086)
# Train Epoch: 12 [9216/9500 (97%)]		Loss: 1.865 (1.901)		Time Dataloader: 0.002 (0.007)		Time Network: 0.059 (0.085)
# Done. This took  0: 2 min.
# Start testing epoch 12
# Test Epoch: 12 [0/500 (0%)]		Loss: 1.757 (1.757)		Time Dataloader: 0.085 (0.085)		Time Network: 0.052 (0.052)
# Done. This took  0: 0 min.
# Saving model to 02_training/model_latest.pt. Done.
# Finished training epoch 12.
#
#
# Start training epoch 13 with lr [9.549150281252635e-06]
# Train Epoch: 13 [0/9500 (0%)]		Loss: 1.826 (1.826)		Time Dataloader: 0.091 (0.091)		Time Network: 0.216 (0.216)
# Train Epoch: 13 [512/9500 (5%)]		Loss: 1.919 (1.872)		Time Dataloader: 0.003 (0.047)		Time Network: 0.082 (0.149)
# Train Epoch: 13 [1024/9500 (11%)]		Loss: 1.923 (1.889)		Time Dataloader: 0.003 (0.032)		Time Network: 0.074 (0.124)
# Train Epoch: 13 [1536/9500 (16%)]		Loss: 1.966 (1.908)		Time Dataloader: 0.002 (0.025)		Time Network: 0.081 (0.113)
# Train Epoch: 13 [2048/9500 (22%)]		Loss: 1.896 (1.906)		Time Dataloader: 0.003 (0.020)		Time Network: 0.081 (0.107)
# Train Epoch: 13 [2560/9500 (27%)]		Loss: 1.864 (1.899)		Time Dataloader: 0.002 (0.017)		Time Network: 0.107 (0.107)
# Train Epoch: 13 [3072/9500 (32%)]		Loss: 1.900 (1.899)		Time Dataloader: 0.003 (0.015)		Time Network: 0.075 (0.102)
# Train Epoch: 13 [3584/9500 (38%)]		Loss: 1.950 (1.905)		Time Dataloader: 0.003 (0.014)		Time Network: 0.076 (0.099)
# Train Epoch: 13 [4096/9500 (43%)]		Loss: 1.850 (1.899)		Time Dataloader: 0.003 (0.012)		Time Network: 0.076 (0.096)
# Train Epoch: 13 [4608/9500 (49%)]		Loss: 1.849 (1.894)		Time Dataloader: 0.002 (0.011)		Time Network: 0.093 (0.096)
# Train Epoch: 13 [5120/9500 (54%)]		Loss: 1.902 (1.895)		Time Dataloader: 0.003 (0.011)		Time Network: 0.077 (0.094)
# Train Epoch: 13 [5632/9500 (59%)]		Loss: 1.809 (1.888)		Time Dataloader: 0.002 (0.010)		Time Network: 0.087 (0.094)
# Train Epoch: 13 [6144/9500 (65%)]		Loss: 1.822 (1.883)		Time Dataloader: 0.003 (0.009)		Time Network: 0.086 (0.093)
# Train Epoch: 13 [6656/9500 (70%)]		Loss: 1.869 (1.882)		Time Dataloader: 0.002 (0.009)		Time Network: 0.080 (0.092)
# Train Epoch: 13 [7168/9500 (75%)]		Loss: 1.833 (1.879)		Time Dataloader: 0.003 (0.008)		Time Network: 0.074 (0.091)
# Train Epoch: 13 [7680/9500 (81%)]		Loss: 1.812 (1.874)		Time Dataloader: 0.002 (0.008)		Time Network: 0.073 (0.090)
# Train Epoch: 13 [8192/9500 (86%)]		Loss: 1.872 (1.874)		Time Dataloader: 0.003 (0.008)		Time Network: 0.074 (0.089)
# Train Epoch: 13 [8704/9500 (92%)]		Loss: 1.900 (1.876)		Time Dataloader: 0.002 (0.007)		Time Network: 0.068 (0.088)
# Train Epoch: 13 [9216/9500 (97%)]		Loss: 1.816 (1.874)		Time Dataloader: 0.002 (0.007)		Time Network: 0.068 (0.087)
# Done. This took  0: 2 min.
# Start testing epoch 13
# Test Epoch: 13 [0/500 (0%)]		Loss: 1.735 (1.735)		Time Dataloader: 0.084 (0.084)		Time Network: 0.059 (0.059)
# Done. This took  0: 0 min.
# Saving model to 02_training/model_latest.pt. Done.
# Finished training epoch 13.
#
#
# Start training epoch 14 with lr [4.322727117869952e-06]
# Train Epoch: 14 [0/9500 (0%)]		Loss: 1.864 (1.864)		Time Dataloader: 0.096 (0.096)		Time Network: 0.208 (0.208)
# Train Epoch: 14 [512/9500 (5%)]		Loss: 1.916 (1.890)		Time Dataloader: 0.003 (0.049)		Time Network: 0.082 (0.145)
# Train Epoch: 14 [1024/9500 (11%)]		Loss: 1.903 (1.895)		Time Dataloader: 0.004 (0.034)		Time Network: 0.075 (0.122)
# Train Epoch: 14 [1536/9500 (16%)]		Loss: 1.826 (1.877)		Time Dataloader: 0.001 (0.026)		Time Network: 0.074 (0.110)
# Train Epoch: 14 [2048/9500 (22%)]		Loss: 1.903 (1.882)		Time Dataloader: 0.002 (0.021)		Time Network: 0.077 (0.103)
# Train Epoch: 14 [2560/9500 (27%)]		Loss: 1.834 (1.874)		Time Dataloader: 0.003 (0.018)		Time Network: 0.081 (0.099)
# Train Epoch: 14 [3072/9500 (32%)]		Loss: 1.844 (1.870)		Time Dataloader: 0.002 (0.016)		Time Network: 0.084 (0.097)
# Train Epoch: 14 [3584/9500 (38%)]		Loss: 1.811 (1.863)		Time Dataloader: 0.002 (0.014)		Time Network: 0.084 (0.095)
# Train Epoch: 14 [4096/9500 (43%)]		Loss: 1.876 (1.864)		Time Dataloader: 0.003 (0.013)		Time Network: 0.073 (0.093)
# Train Epoch: 14 [4608/9500 (49%)]		Loss: 1.928 (1.871)		Time Dataloader: 0.002 (0.012)		Time Network: 0.074 (0.091)
# Train Epoch: 14 [5120/9500 (54%)]		Loss: 1.940 (1.877)		Time Dataloader: 0.003 (0.011)		Time Network: 0.072 (0.089)
# Train Epoch: 14 [5632/9500 (59%)]		Loss: 1.859 (1.875)		Time Dataloader: 0.003 (0.010)		Time Network: 0.074 (0.088)
# Train Epoch: 14 [6144/9500 (65%)]		Loss: 1.869 (1.875)		Time Dataloader: 0.002 (0.010)		Time Network: 0.075 (0.087)
# Train Epoch: 14 [6656/9500 (70%)]		Loss: 1.897 (1.877)		Time Dataloader: 0.003 (0.009)		Time Network: 0.121 (0.090)
# Train Epoch: 14 [7168/9500 (75%)]		Loss: 1.970 (1.883)		Time Dataloader: 0.003 (0.009)		Time Network: 0.072 (0.088)
# Train Epoch: 14 [7680/9500 (81%)]		Loss: 1.829 (1.879)		Time Dataloader: 0.002 (0.008)		Time Network: 0.072 (0.087)
# Train Epoch: 14 [8192/9500 (86%)]		Loss: 1.770 (1.873)		Time Dataloader: 0.003 (0.008)		Time Network: 0.072 (0.087)
# Train Epoch: 14 [8704/9500 (92%)]		Loss: 1.815 (1.870)		Time Dataloader: 0.003 (0.008)		Time Network: 0.073 (0.086)
# Train Epoch: 14 [9216/9500 (97%)]		Loss: 1.892 (1.870)		Time Dataloader: 0.002 (0.007)		Time Network: 0.062 (0.084)
# Done. This took  0: 2 min.
# Start testing epoch 14
# Test Epoch: 14 [0/500 (0%)]		Loss: 1.707 (1.707)		Time Dataloader: 0.087 (0.087)		Time Network: 0.051 (0.051)
# Done. This took  0: 0 min.
# Saving model to 02_training/model_latest.pt. Done.
# Finished training epoch 14.
#
#
# Start training epoch 15 with lr [1.092619963309716e-06]
# Train Epoch: 15 [0/9500 (0%)]		Loss: 1.920 (1.920)		Time Dataloader: 0.096 (0.096)		Time Network: 0.222 (0.222)
# Train Epoch: 15 [512/9500 (5%)]		Loss: 1.788 (1.854)		Time Dataloader: 0.003 (0.049)		Time Network: 0.090 (0.156)
# Train Epoch: 15 [1024/9500 (11%)]		Loss: 1.807 (1.838)		Time Dataloader: 0.003 (0.034)		Time Network: 0.079 (0.130)
# Train Epoch: 15 [1536/9500 (16%)]		Loss: 1.881 (1.849)		Time Dataloader: 0.003 (0.026)		Time Network: 0.075 (0.117)
# Train Epoch: 15 [2048/9500 (22%)]		Loss: 1.770 (1.833)		Time Dataloader: 0.002 (0.021)		Time Network: 0.084 (0.110)
# Train Epoch: 15 [2560/9500 (27%)]		Loss: 1.969 (1.856)		Time Dataloader: 0.002 (0.018)		Time Network: 0.075 (0.104)
# Train Epoch: 15 [3072/9500 (32%)]		Loss: 1.801 (1.848)		Time Dataloader: 0.002 (0.016)		Time Network: 0.077 (0.100)
# Train Epoch: 15 [3584/9500 (38%)]		Loss: 1.857 (1.849)		Time Dataloader: 0.002 (0.014)		Time Network: 0.080 (0.098)
# Train Epoch: 15 [4096/9500 (43%)]		Loss: 1.914 (1.856)		Time Dataloader: 0.002 (0.013)		Time Network: 0.077 (0.095)
# Train Epoch: 15 [4608/9500 (49%)]		Loss: 1.835 (1.854)		Time Dataloader: 0.002 (0.012)		Time Network: 0.076 (0.093)
# Train Epoch: 15 [5120/9500 (54%)]		Loss: 1.870 (1.855)		Time Dataloader: 0.003 (0.011)		Time Network: 0.088 (0.093)
# Train Epoch: 15 [5632/9500 (59%)]		Loss: 1.850 (1.855)		Time Dataloader: 0.002 (0.010)		Time Network: 0.072 (0.091)
# Train Epoch: 15 [6144/9500 (65%)]		Loss: 1.931 (1.861)		Time Dataloader: 0.003 (0.010)		Time Network: 0.087 (0.091)
# Train Epoch: 15 [6656/9500 (70%)]		Loss: 1.930 (1.866)		Time Dataloader: 0.003 (0.009)		Time Network: 0.078 (0.090)
# Train Epoch: 15 [7168/9500 (75%)]		Loss: 1.850 (1.865)		Time Dataloader: 0.003 (0.009)		Time Network: 0.078 (0.089)
# Train Epoch: 15 [7680/9500 (81%)]		Loss: 1.845 (1.863)		Time Dataloader: 0.002 (0.008)		Time Network: 0.073 (0.088)
# Train Epoch: 15 [8192/9500 (86%)]		Loss: 1.916 (1.867)		Time Dataloader: 0.003 (0.008)		Time Network: 0.080 (0.088)
# Train Epoch: 15 [8704/9500 (92%)]		Loss: 1.876 (1.867)		Time Dataloader: 0.003 (0.008)		Time Network: 0.070 (0.087)
# Train Epoch: 15 [9216/9500 (97%)]		Loss: 1.921 (1.869)		Time Dataloader: 0.002 (0.007)		Time Network: 0.056 (0.085)
# Done. This took  0: 2 min.
# Start testing epoch 15
# Test Epoch: 15 [0/500 (0%)]		Loss: 1.719 (1.719)		Time Dataloader: 0.084 (0.084)		Time Network: 0.055 (0.055)
# Done. This took  0: 0 min.
# Saving model to 02_training/model_latest.pt. Done.
# Copy model to checkpoint 02_training/model_015.pt. Done.
# Finished training epoch 15.
#
# Stop run: Total epoch limit of 15 reached.
# Training stage complete. Saving to 02_training/model_stage_0.pt.
# All training stages complete.

# %% [markdown]
# The loss values are stored in `history.txt`, which contains as columns: epoch number, training loss, validation loss, and learning rate.
#
# One can load this file and plot the training and validation loss:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load history.txt
filename = '02_training/history.txt'
data = np.loadtxt(filename, delimiter="\t")

# Plot loss values
plt.plot(data[:,0], data[:,1], label=f"training loss")
plt.plot(data[:,0], data[:,2], label=f"validation loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend();

# %% [markdown]
# ## 4. Injections
#
# Here, we use the **Sampler API** to [prepare and run an injection](https://dingo-gw.readthedocs.io/en/latest/example_injection.html).
# 1. Load the model `dingo.core.models.posterior_model.PosteriorModel` into the `dingo.gw.inference.gw_samplers.GWSampler` class.
# 2. Instantiate the `dingo.gw.injection.Injection` class based on the settings the posterior model was trained on (accessible via `PosteriorModel.metadata`).
# 3. Specify an ASD dataset, e.g. the fiducial ASD dataset the network was trained on.
# 4. Sample from the prior and generate an injection.
# 5. Insert the generated injection data into the sampler through `sampler.context`.
# 6. Generate samples and convert the sampler instance into a `dingo.gw.result.Result`.
# 7. Run importance sampling on the result object.
# 8. Visualize the corner plot and save the result.
#
# This approach is designed to produce injections entirely consistent with training data.

# %%
from dingo.core.posterior_models.normalizing_flow import NormalizingFlowPosteriorModel
from dingo.gw.inference.gw_samplers import GWSampler
from dingo.gw.injection import Injection

# %%
from dingo.gw.noise.asd_dataset import ASDDataset

model_path = "02_training/model_latest.pt"
asd_path = "01_training_data/asd_dataset/asd_GW150914.hdf5"

# Load the network into the GWSampler class
pm = NormalizingFlowPosteriorModel(model_filename=model_path, device="cpu")
sampler = GWSampler(model=pm)

# Generate an injection consistent with the data the model was trained on.
injection = Injection.from_posterior_model_metadata(pm.metadata)
injection.asd = ASDDataset(asd_path, ifos=["H1", "L1"])
theta = injection.prior.sample()  # Random injection from prior.
inj = injection.injection(theta)

# Generate 10,000 samples from the DINGO model based on the generated injection data.
sampler.context = inj
sampler.run_sampler(10_000)
result = sampler.to_result()

# The following are only needed for importance-sampling the result.
result.importance_sample(num_processes=1)

# Make a corner plot and save the result.
result.print_summary()
kwargs = {"legend_font_size": 15, "truth_color": "black"}
parameters = ['chirp_mass', 'mass_ratio']
truths = [v for k,v in theta.items() if k in parameters]
result.plot_corner(parameters=parameters,
                   filename="03_inference/injection/corner.pdf",
                   truths=truths,
                   **kwargs)
result.to_file("03_inference/injection/result.hdf5")
# Out:
# Putting posterior model to device cpu.
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# Loading dataset from 01_training_data/asd_dataset/asd_GW150914.hdf5.
# Updating ASDDataset domain to match data domain.
# Running sampler to generate 10000 samples.
# Adding fixed parameter a_1 = 0.925635814666748 from prior.
# Adding fixed parameter a_2 = 0.5538952350616455 from prior.
# Adding fixed parameter geocent_time = 0.011423417367041111 from prior.
# Adding fixed parameter luminosity_distance = 488.2327880859375 from prior.
# Adding fixed parameter phase = 0.9604566579018894 from prior.
# Adding fixed parameter phi_jl = 5.561878204345703 from prior.
# Adding fixed parameter theta_jn = 2.624497413635254 from prior.
# Adding fixed parameter tilt_1 = 2.0111560821533203 from prior.
# Adding fixed parameter tilt_2 = 1.0743615627288818 from prior.
# Adding fixed parameter dec = -1.2616009712219238 from prior.
# Adding fixed parameter ra = 1.4557750225067139 from prior.
# Adding fixed parameter psi = 1.2124483585357666 from prior.
# Done. This took 0.1 s.
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# Calculating 8141 likelihoods.

# %% [markdown]
# Since we trained the model in a simplified setting (small waveform dataset, small model, short training), we don't expect high sample efficiencies (> 1%).

# %% [markdown]
# ## 5. Real events with `dingo_pipe`
#
# Dingo includes a command-line tool [`dingo_pipe`](https://dingo-gw.readthedocs.io/en/latest/dingo_pipe.html) for automating inference tasks. This is based very closely on the [`bilby_pipe`](https://lscsoft.docs.ligo.org/bilby_pipe/master/user-interface.html) package, with suitable modifications.
#
# **Step 1: Prepare `.ini` file for `dingo_pipe`.**
# Similar to `bilby_pipe`, `dingo_pipe` requires an `.ini` file as an input that specifies the arguments of the subsequently performed steps.
# 1. **Job submission arguments**: Specify cluster and system specific details here.
# 2. **Sampler arguments**: Determine which model should be used to generate the samples.
# 3. **Data generation arguments**: Define which event data should be downloaded.
# 4. **Plotting arguments**: Specify which plots should be generated automatically.

# %%
dingo_pipe_GW150914 = """
################################################################################
##  Job submission arguments
################################################################################

local = True
submit = False
accounting = dingo.GW150914
request-cpus-importance-sampling = 1
simple-submission = False

################################################################################
##  Sampler arguments
################################################################################

model = 02_training/model_latest.pt
device = cpu
num-samples = 5000
batch-size = 5000
importance-sampling-settings = {}

################################################################################
## Data generation arguments
################################################################################

trigger-time = 1126259462.3885767 # GW150914 # condition network on maxlog geocent time 1126259462.4 - 0.011423417367041111
label = GW150914
outdir = 03_inference/outdir_GW150914
channel-dict = {H1:GWOSC, L1:GWOSC}
psd-length = 128
# sampling-frequency = 2048.0
# importance-sampling-updates = {'duration': 4.0}

################################################################################
## Plotting arguments
################################################################################

plot-corner = true
plot-weights = true
plot-log-probs = true
"""
with open('03_inference/GW150914.ini', 'w') as outfile:
    outfile.write(dingo_pipe_GW150914)

# %%
# !dingo_pipe 03_inference/GW150914.ini
# Out:
# 260331_120426 INFO: Loading dingo model from 02_training/model_latest.pt in order to access settings.
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# 260331_120426 INFO: Setting analysis request_cpus_importance_sampling = 1
# 260331_120426 INFO: Using a non-'dingo' accounting tag: please ensure this is intentional
# 260331_120426 INFO: Using accounting tag: dingo.GW150914
# 260331_120426 INFO: Using accounting-user: None
# 260331_120426 INFO: Setting segment trigger-times [1126259462.3885767]
# 260331_120426 INFO: Skipping datafind for H1 as GWOSC data is used.
# 260331_120426 INFO: Skipping datafind for L1 as GWOSC data is used.
# 260331_120426 INFO: Running command: /home/yyyz/miniconda3/envs/dingo/bin/dingo_pipe_generation 03_inference/outdir_GW150914/GW150914_config_complete.ini --label GW150914_data0_1126259462-3885767_generation --idx 0 --trigger-time 1126259462.3885767 --outdir 03_inference/outdir_GW150914
# 260331_120428 WARNING: You do not have nds2 (python-nds2-client) installed. You may  experience problems accessing interferometer data.
# 260331_120428 WARNING: You do not have LDAStools.frameCPP (python-ldas-tools-framecpp) installed. You may experience problems accessing interferometer data.
# 260331_120429 INFO: Command line arguments: Namespace(ini='03_inference/outdir_GW150914/GW150914_config_complete.ini', verbose=False, calibration_model=None, calibration_mode='marginalize', calibration_correction_type=None, spline_calibration_envelope_dict=None, spline_calibration_nodes=10, spline_calibration_curves=1000, idx=0, data_dump_file=None, event_data_file=None, proposal_samples_file=None, importance_sampling_generation=False, ignore_gwpy_data_quality_check=True, gps_tuple=None, gps_file=None, timeslide_file=None, timeslide_dict=None, trigger_time='1126259462.3885767', n_simulation=0, data_dict=None, data_format=None, allow_tape=True, channel_dict='{H1:GWOSC, L1:GWOSC}', fetch_open_data_kwargs=None, frame_type_dict=None, data_find_url=None, data_find_urltype='osdf', gaussian_noise=False, zero_noise=False, detectors=['H1', 'L1'], duration=2.0, generation_seed=None, psd_dict=None, asd_dataset=None, psd_fractional_overlap=0.0, post_trigger_duration=2.0, sampling_frequency=4096.0, psd_length=128, psd_maximum_duration=1024, psd_method='median', psd_start_time=None, maximum_frequency='256.0', minimum_frequency='20.0', tukey_roll_off=1.0, resampling_method='lal', injection=False, injection_dict=None, injection_file=None, injection_numbers=[None], dingo_injection=False, injection_waveform_approximant=None, injection_frequency_domain_source_model=None, injection_waveform_arguments=None, injection_waveform_generator_constructor_dict=None, save_bilby_data_dump=False, accounting='dingo.GW150914', accounting_user=None, label='GW150914_data0_1126259462-3885767_generation', local=True, local_generation=False, generation_pool='local-pool', local_plot=False, outdir='03_inference/outdir_GW150914', overwrite_outdir=False, request_disk=5.0, request_memory_generation=8.0, request_memory=8.0, request_cpus=1, request_memory_importance_sampling=8.0, request_cpus_importance_sampling=1, conda_env=None, sampling_requirements=['None'], extra_lines=['None'], simple_submission=False, scheduler='condor', scheduler_args=None, scheduler_module=[None], scheduler_env=None, scheduler_analysis_time='7-00:00:00', submit=False, condor_job_priority=0, transfer_files=True, environment_variables=None, getenv=[None], additional_transfer_paths=[None], disable_hdf5_locking=False, log_directory=None, osg=False, gpu_desired_sites=None, cpu_desired_sites=None, generation_desired_sites=None, analysis_executable=None, analysis_executable_parser=None, scitoken_issuer=None, container=None, time_reference='geocent', plot_data=False, plot_injection=False, plot_spectrogram=False, plot_corner=True, plot_weights=True, plot_log_probs=True, plot_pp=False, create_summary=False, email=None, notification='Never', queue=None, existing_dir=None, webdir=None, summarypages_arguments=None, result_format='hdf5', final_result=True, final_result_nsamples=20000, default_prior='BBHPriorDict', deltaT=0.0, Toffset=0.011423417367041111, prior_dict_updates=None, prior_file=None, prior_dict="{a_1:DeltaFunction(peak=0.925635814666748, name=None, latex_label=None, unit=None), a_2:DeltaFunction(peak=0.5538952350616455, name=None, latex_label=None, unit=None), chirp_mass:bilby.gw.prior.UniformInComponentsChirpMass(minimum=15.0, maximum=50.0, name='chirp_mass', latex_label='$\\\\mathcal{M}$', unit=None, boundary=None), luminosity_distance:DeltaFunction(peak=488.2327880859375, name=None, latex_label=None, unit=None), mass_ratio:bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False), phase:DeltaFunction(peak=0.9604566579018894, name=None, latex_label=None, unit=None), phi_jl:DeltaFunction(peak=5.561878204345703, name=None, latex_label=None, unit=None), theta_jn:DeltaFunction(peak=2.624497413635254, name=None, latex_label=None, unit=None), tilt_1:DeltaFunction(peak=2.0111560821533203, name=None, latex_label=None, unit=None), tilt_2:DeltaFunction(peak=1.0743615627288818, name=None, latex_label=None, unit= ...
# 260331_120429 INFO: Unknown command line arguments: []
# 260331_120429 INFO: Generation seed set to 784349
# 260331_120429 INFO: Setting PSD for H1 from data
# 260331_120429 INFO: Using default PSD start time -256.0 relative to start time
# 260331_120429 INFO: Getting psd-segment data for H1
# 260331_120429 INFO: Attempting to download data from GWOSC
# 260331_120429 INFO: Running: gwpy.timeseries.TimeSeries.fetch_open_data(ifo='H1', start=1126259206.3885767, end=1126259462.3885767, sample_rate=16384, )
# Traceback (most recent call last):
#   File "/home/yyyz/miniconda3/envs/dingo/bin/dingo_pipe_generation", line 6, in <module>
#     sys.exit(main())
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/dingo/pipe/data_generation.py", line 537, in main
#     data = DataGenerationInput(args, unknown_args)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/dingo/pipe/data_generation.py", line 213, in __init__
#     self.create_data(args)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/data_generation.py", line 263, in create_data
#     self._set_interferometers_from_data()
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/data_generation.py", line 539, in _set_interferometers_from_data
#     psd_data = self.__get_psd_data(det)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/data_generation.py", line 568, in __get_psd_data
#     psd_data = self._get_data(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/data_generation.py", line 692, in _get_data
#     data = self._gwpy_fetch_open_data(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/data_generation.py", line 1016, in _gwpy_fetch_open_data
#     data = gwpy.timeseries.TimeSeries.fetch_open_data(**kwargs)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/gwpy/timeseries/core.py", line 475, in fetch_open_data
#     return fetch_gwosc_data(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/gwpy/timeseries/io/losc.py", line 194, in fetch_gwosc_data
#     new = _fetch_gwosc_data_file(url, *args, **kwargs)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/gwpy/timeseries/io/losc.py", line 94, in _fetch_gwosc_data_file
#     with _download_file(url, cache, verbose=verbose, timeout=timeout) as rem:
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/contextlib.py", line 135, in __enter__
#     return next(self.gen)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/astropy/utils/data.py", line 358, in get_readable_fileobj
#     name_or_obj = download_file(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/astropy/utils/data.py", line 1531, in download_file
#     f_name = _download_file_from_source(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/astropy/utils/data.py", line 1358, in _download_file_from_source
#     block = remote.read(conf.download_block_size)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/http/client.py", line 471, in read
#     s = self.fp.read(amt)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/socket.py", line 717, in readinto
#     return self._sock.recv_into(b)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/ssl.py", line 1307, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/ssl.py", line 1163, in read
#     return self._sslobj.read(len, buffer)
# TimeoutError: The read operation timed out
# Traceback (most recent call last):
#   File "/home/yyyz/miniconda3/envs/dingo/bin/dingo_pipe", line 6, in <module>
#     sys.exit(main())
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/dingo/pipe/main.py", line 628, in main
#     generate_dag(inputs)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/dingo/pipe/dag_creator.py", line 67, in generate_dag
#     generation_node = GenerationNode(inputs, **kwargs)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/dingo/pipe/nodes/generation_node.py", line 121, in __init__
#     self.process_node()
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/job_creation/node.py", line 50, in process_node
#     subprocess.run([self.executable] + self.arguments.argument_list, check=True)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/subprocess.py", line 526, in run
#     raise CalledProcessError(retcode, process.args,
# subprocess.CalledProcessError: Command '['/home/yyyz/miniconda3/envs/dingo/bin/dingo_pipe_generation', '03_inference/outdir_GW150914/GW150914_config_complete.ini', '--label', 'GW150914_data0_1126259462-3885767_generation', '--idx', '0', '--trigger-time', '1126259462.3885767', '--outdir', '03_inference/outdir_GW150914']' returned non-zero exit status 1.

# %% [markdown]
# **Step 2: Run `dingo_pipe` for GW150914**
#
# If `local=True`, you can run all steps of `dingo_pipe` automatically by executing the following command:

# %%
# !dingo_pipe 03_inference/GW150914.ini
# Out:
# 260331_175934 INFO: Loading dingo model from 02_training/model_latest.pt in order to access settings.
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# 260331_175934 INFO: Setting analysis request_cpus_importance_sampling = 1
# 260331_175934 INFO: Using a non-'dingo' accounting tag: please ensure this is intentional
# 260331_175934 INFO: Using accounting tag: dingo.GW150914
# 260331_175934 INFO: Using accounting-user: None
# 260331_175934 WARNING: File 03_inference/outdir_GW150914/GW150914_config_complete.ini already exists, not writing to file.
# 260331_175934 INFO: Setting segment trigger-times [1126259462.3885767]
# 260331_175934 INFO: Skipping datafind for H1 as GWOSC data is used.
# 260331_175934 INFO: Skipping datafind for L1 as GWOSC data is used.
# 260331_175934 INFO: Running command: /home/yyyz/miniconda3/envs/dingo/bin/dingo_pipe_generation 03_inference/outdir_GW150914/GW150914_config_complete.ini --label GW150914_data0_1126259462-3885767_generation --idx 0 --trigger-time 1126259462.3885767 --outdir 03_inference/outdir_GW150914
# 260331_175936 WARNING: You do not have nds2 (python-nds2-client) installed. You may  experience problems accessing interferometer data.
# 260331_175936 WARNING: You do not have LDAStools.frameCPP (python-ldas-tools-framecpp) installed. You may experience problems accessing interferometer data.
# 260331_175937 INFO: Command line arguments: Namespace(ini='03_inference/outdir_GW150914/GW150914_config_complete.ini', verbose=False, calibration_model=None, calibration_mode='marginalize', calibration_correction_type=None, spline_calibration_envelope_dict=None, spline_calibration_nodes=10, spline_calibration_curves=1000, idx=0, data_dump_file=None, event_data_file=None, proposal_samples_file=None, importance_sampling_generation=False, ignore_gwpy_data_quality_check=True, gps_tuple=None, gps_file=None, timeslide_file=None, timeslide_dict=None, trigger_time='1126259462.3885767', n_simulation=0, data_dict=None, data_format=None, allow_tape=True, channel_dict='{H1:GWOSC, L1:GWOSC}', fetch_open_data_kwargs=None, frame_type_dict=None, data_find_url=None, data_find_urltype='osdf', gaussian_noise=False, zero_noise=False, detectors=['H1', 'L1'], duration=2.0, generation_seed=None, psd_dict=None, asd_dataset=None, psd_fractional_overlap=0.0, post_trigger_duration=2.0, sampling_frequency=2048.0, psd_length=128, psd_maximum_duration=1024, psd_method='median', psd_start_time=None, maximum_frequency='256.0', minimum_frequency='20.0', tukey_roll_off=1.0, resampling_method='lal', injection=False, injection_dict=None, injection_file=None, injection_numbers=[None], dingo_injection=False, injection_waveform_approximant=None, injection_frequency_domain_source_model=None, injection_waveform_arguments=None, injection_waveform_generator_constructor_dict=None, save_bilby_data_dump=False, accounting='dingo.GW150914', accounting_user=None, label='GW150914_data0_1126259462-3885767_generation', local=True, local_generation=False, generation_pool='local-pool', local_plot=False, outdir='03_inference/outdir_GW150914', overwrite_outdir=False, request_disk=5.0, request_memory_generation=8.0, request_memory=8.0, request_cpus=1, request_memory_importance_sampling=8.0, request_cpus_importance_sampling=1, conda_env=None, sampling_requirements=['None'], extra_lines=['None'], simple_submission=False, scheduler='condor', scheduler_args=None, scheduler_module=[None], scheduler_env=None, scheduler_analysis_time='7-00:00:00', submit=False, condor_job_priority=0, transfer_files=True, environment_variables=None, getenv=[None], additional_transfer_paths=[None], disable_hdf5_locking=False, log_directory=None, osg=False, gpu_desired_sites=None, cpu_desired_sites=None, generation_desired_sites=None, analysis_executable=None, analysis_executable_parser=None, scitoken_issuer=None, container=None, time_reference='geocent', plot_data=False, plot_injection=False, plot_spectrogram=False, plot_corner=True, plot_weights=True, plot_log_probs=True, plot_pp=False, create_summary=False, email=None, notification='Never', queue=None, existing_dir=None, webdir=None, summarypages_arguments=None, result_format='hdf5', final_result=True, final_result_nsamples=20000, default_prior='BBHPriorDict', deltaT=0.0, Toffset=0.011423417367041111, prior_dict_updates=None, prior_file=None, prior_dict="{a_1:DeltaFunction(peak=0.925635814666748, name=None, latex_label=None, unit=None), a_2:DeltaFunction(peak=0.5538952350616455, name=None, latex_label=None, unit=None), chirp_mass:bilby.gw.prior.UniformInComponentsChirpMass(minimum=15.0, maximum=50.0, name='chirp_mass', latex_label='$\\\\mathcal{M}$', unit=None, boundary=None), luminosity_distance:DeltaFunction(peak=488.2327880859375, name=None, latex_label=None, unit=None), mass_ratio:bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False), phase:DeltaFunction(peak=0.9604566579018894, name=None, latex_label=None, unit=None), phi_jl:DeltaFunction(peak=5.561878204345703, name=None, latex_label=None, unit=None), theta_jn:DeltaFunction(peak=2.624497413635254, name=None, latex_label=None, unit=None), tilt_1:DeltaFunction(peak=2.0111560821533203, name=None, latex_label=None, unit=None), tilt_2:DeltaFunction(peak=1.0743615627288818, name=None, latex_label=None, unit= ...
# 260331_175937 INFO: Unknown command line arguments: []
# 260331_175937 INFO: Generation seed set to 393974
# 260331_175937 INFO: Setting PSD for H1 from data
# 260331_175937 INFO: Using default PSD start time -256.0 relative to start time
# 260331_175937 INFO: Getting psd-segment data for H1
# 260331_175937 INFO: Attempting to download data from GWOSC
# 260331_175937 INFO: Running: gwpy.timeseries.TimeSeries.fetch_open_data(ifo='H1', start=1126259206.3885767, end=1126259462.3885767, sample_rate=16384, )
# 260331_181809 INFO: Resampling data to sampling_frequency 2048.0 using lal
# 260331_181810 INFO: PSD settings: window=Tukey, Tukey-alpha=1.0 roll-off=1.0, overlap=0.0, method=median
# 260331_181810 INFO: Getting analysis-segment data for H1
# 260331_181810 INFO: Attempting to download data from GWOSC
# 260331_181810 INFO: Running: gwpy.timeseries.TimeSeries.fetch_open_data(ifo='H1', start=1126259462.3885767, end=1126259464.3885767, sample_rate=16384, )
# 260331_183154 INFO: Resampling data to sampling_frequency 2048.0 using lal
# 260331_183154 INFO: Setting PSD for L1 from data
# 260331_183154 INFO: Using default PSD start time -256.0 relative to start time
# 260331_183154 INFO: Getting psd-segment data for L1
# 260331_183154 INFO: Attempting to download data from GWOSC
# 260331_183154 INFO: Running: gwpy.timeseries.TimeSeries.fetch_open_data(ifo='L1', start=1126259206.3885767, end=1126259462.3885767, sample_rate=16384, )
# 260331_184138 INFO: Resampling data to sampling_frequency 2048.0 using lal
# 260331_184138 INFO: PSD settings: window=Tukey, Tukey-alpha=1.0 roll-off=1.0, overlap=0.0, method=median
# 260331_184138 INFO: Getting analysis-segment data for L1
# 260331_184138 INFO: Attempting to download data from GWOSC
# 260331_184138 INFO: Running: gwpy.timeseries.TimeSeries.fetch_open_data(ifo='L1', start=1126259462.3885767, end=1126259464.3885767, sample_rate=16384, )
# 260331_185149 INFO: Resampling data to sampling_frequency 2048.0 using lal
# 260331_185149 INFO: Using default PSD start time -256.0 relative to start time
# Saving dataset to 03_inference/outdir_GW150914/data/GW150914_data0_1126259462-3885767_generation_event_data.hdf5
# 260331_185149 INFO: Completed data generation
# 260331_185150 INFO: Running command: /home/yyyz/miniconda3/envs/dingo/bin/dingo_pipe_sampling 03_inference/outdir_GW150914/GW150914_config_complete.ini --label GW150914_data0_1126259462-3885767_sampling --event-data-file 03_inference/outdir_GW150914/data/GW150914_data0_1126259462-3885767_generation_event_data.hdf5 --outdir 03_inference/outdir_GW150914
# 260331_185154 INFO: Command line arguments: Namespace(ini='03_inference/outdir_GW150914/GW150914_config_complete.ini', verbose=False, calibration_model=None, calibration_mode='marginalize', calibration_correction_type=None, spline_calibration_envelope_dict=None, spline_calibration_nodes=10, spline_calibration_curves=1000, idx=0, data_dump_file=None, event_data_file='03_inference/outdir_GW150914/data/GW150914_data0_1126259462-3885767_generation_event_data.hdf5', proposal_samples_file=None, importance_sampling_generation=False, ignore_gwpy_data_quality_check=True, gps_tuple=None, gps_file=None, timeslide_file=None, timeslide_dict=None, trigger_time='1126259462.3885767', n_simulation=0, data_dict=None, data_format=None, allow_tape=True, channel_dict='{H1:GWOSC, L1:GWOSC}', fetch_open_data_kwargs=None, frame_type_dict=None, data_find_url=None, data_find_urltype='osdf', gaussian_noise=False, zero_noise=False, detectors=['H1', 'L1'], duration=2.0, generation_seed=None, psd_dict=None, asd_dataset=None, psd_fractional_overlap=0.0, post_trigger_duration=2.0, sampling_frequency=2048.0, psd_length=128, psd_maximum_duration=1024, psd_method='median', psd_start_time=None, maximum_frequency='256.0', minimum_frequency='20.0', tukey_roll_off=1.0, resampling_method='lal', injection=False, injection_dict=None, injection_file=None, injection_numbers=[None], dingo_injection=False, injection_waveform_approximant=None, injection_frequency_domain_source_model=None, injection_waveform_arguments=None, injection_waveform_generator_constructor_dict=None, save_bilby_data_dump=False, accounting='dingo.GW150914', accounting_user=None, label='GW150914_data0_1126259462-3885767_sampling', local=True, local_generation=False, generation_pool='local-pool', local_plot=False, outdir='03_inference/outdir_GW150914', overwrite_outdir=False, request_disk=5.0, request_memory_generation=8.0, request_memory=8.0, request_cpus=1, request_memory_importance_sampling=8.0, request_cpus_importance_sampling=1, conda_env=None, sampling_requirements=['None'], extra_lines=['None'], simple_submission=False, scheduler='condor', scheduler_args=None, scheduler_module=[None], scheduler_env=None, scheduler_analysis_time='7-00:00:00', submit=False, condor_job_priority=0, transfer_files=True, environment_variables=None, getenv=[None], additional_transfer_paths=[None], disable_hdf5_locking=False, log_directory=None, osg=False, gpu_desired_sites=None, cpu_desired_sites=None, generation_desired_sites=None, analysis_executable=None, analysis_executable_parser=None, scitoken_issuer=None, container=None, time_reference='geocent', plot_data=False, plot_injection=False, plot_spectrogram=False, plot_corner=True, plot_weights=True, plot_log_probs=True, plot_pp=False, create_summary=False, email=None, notification='Never', queue=None, existing_dir=None, webdir=None, summarypages_arguments=None, result_format='hdf5', final_result=True, final_result_nsamples=20000, default_prior='BBHPriorDict', deltaT=0.0, Toffset=0.011423417367041111, prior_dict_updates=None, prior_file=None, prior_dict="{a_1:DeltaFunction(peak=0.925635814666748, name=None, latex_label=None, unit=None), a_2:DeltaFunction(peak=0.5538952350616455, name=None, latex_label=None, unit=None), chirp_mass:bilby.gw.prior.UniformInComponentsChirpMass(minimum=15.0, maximum=50.0, name='chirp_mass', latex_label='$\\\\mathcal{M}$', unit=None, boundary=None), luminosity_distance:DeltaFunction(peak=488.2327880859375, name=None, latex_label=None, unit=None), mass_ratio:bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False), phase:DeltaFunction(peak=0.9604566579018894, name=None, latex_label=None, unit=None), phi_jl:DeltaFunction(peak=5.561878204345703, name=None, latex_label=None, unit=None), theta_jn:DeltaFunction(peak=2.624497413635254, name=None, latex_label=None, unit=None), tilt_1:DeltaFunction(peak=2.0111560821533203, name=None, latex_label=None, un ...
# 260331_185154 INFO: Unknown command line arguments: []
# Loading dataset from 03_inference/outdir_GW150914/data/GW150914_data0_1126259462-3885767_generation_event_data.hdf5.
# Putting posterior model to device cpu.
# Running sampler to generate 5000 samples.
# Adding fixed parameter a_1 = 0.925635814666748 from prior.
# Adding fixed parameter a_2 = 0.5538952350616455 from prior.
# Adding fixed parameter geocent_time = 0.011423417367041111 from prior.
# Adding fixed parameter luminosity_distance = 488.2327880859375 from prior.
# Adding fixed parameter phase = 0.9604566579018894 from prior.
# Adding fixed parameter phi_jl = 5.561878204345703 from prior.
# Adding fixed parameter theta_jn = 2.624497413635254 from prior.
# Adding fixed parameter tilt_1 = 2.0111560821533203 from prior.
# Adding fixed parameter tilt_2 = 1.0743615627288818 from prior.
# Adding fixed parameter dec = -1.2616009712219238 from prior.
# Adding fixed parameter ra = 1.4557750225067139 from prior.
# Adding fixed parameter psi = 1.2124483585357666 from prior.
# Done. This took 0.4 s.
# Saving dataset to 03_inference/outdir_GW150914/result/GW150914_data0_1126259462-3885767_sampling.hdf5
# 260331_185155 INFO: Skipping datafind for H1 as GWOSC data is used.
# 260331_185155 INFO: Skipping datafind for L1 as GWOSC data is used.
# 260331_185155 INFO: Running command: /home/yyyz/miniconda3/envs/dingo/bin/dingo_pipe_generation 03_inference/outdir_GW150914/GW150914_config_complete.ini --importance-sampling-generation --label GW150914_data0_1126259462-3885767_generation_IS --idx 0 --trigger-time 1126259462.3885767 --outdir 03_inference/outdir_GW150914
# 260331_185156 WARNING: You do not have nds2 (python-nds2-client) installed. You may  experience problems accessing interferometer data.
# 260331_185156 WARNING: You do not have LDAStools.frameCPP (python-ldas-tools-framecpp) installed. You may experience problems accessing interferometer data.
# 260331_185157 INFO: Command line arguments: Namespace(ini='03_inference/outdir_GW150914/GW150914_config_complete.ini', verbose=False, calibration_model=None, calibration_mode='marginalize', calibration_correction_type=None, spline_calibration_envelope_dict=None, spline_calibration_nodes=10, spline_calibration_curves=1000, idx=0, data_dump_file=None, event_data_file=None, proposal_samples_file=None, importance_sampling_generation=True, ignore_gwpy_data_quality_check=True, gps_tuple=None, gps_file=None, timeslide_file=None, timeslide_dict=None, trigger_time='1126259462.3885767', n_simulation=0, data_dict=None, data_format=None, allow_tape=True, channel_dict='{H1:GWOSC, L1:GWOSC}', fetch_open_data_kwargs=None, frame_type_dict=None, data_find_url=None, data_find_urltype='osdf', gaussian_noise=False, zero_noise=False, detectors=['H1', 'L1'], duration=2.0, generation_seed=None, psd_dict=None, asd_dataset=None, psd_fractional_overlap=0.0, post_trigger_duration=2.0, sampling_frequency=2048.0, psd_length=128, psd_maximum_duration=1024, psd_method='median', psd_start_time=None, maximum_frequency='256.0', minimum_frequency='20.0', tukey_roll_off=1.0, resampling_method='lal', injection=False, injection_dict=None, injection_file=None, injection_numbers=[None], dingo_injection=False, injection_waveform_approximant=None, injection_frequency_domain_source_model=None, injection_waveform_arguments=None, injection_waveform_generator_constructor_dict=None, save_bilby_data_dump=False, accounting='dingo.GW150914', accounting_user=None, label='GW150914_data0_1126259462-3885767_generation_IS', local=True, local_generation=False, generation_pool='local-pool', local_plot=False, outdir='03_inference/outdir_GW150914', overwrite_outdir=False, request_disk=5.0, request_memory_generation=8.0, request_memory=8.0, request_cpus=1, request_memory_importance_sampling=8.0, request_cpus_importance_sampling=1, conda_env=None, sampling_requirements=['None'], extra_lines=['None'], simple_submission=False, scheduler='condor', scheduler_args=None, scheduler_module=[None], scheduler_env=None, scheduler_analysis_time='7-00:00:00', submit=False, condor_job_priority=0, transfer_files=True, environment_variables=None, getenv=[None], additional_transfer_paths=[None], disable_hdf5_locking=False, log_directory=None, osg=False, gpu_desired_sites=None, cpu_desired_sites=None, generation_desired_sites=None, analysis_executable=None, analysis_executable_parser=None, scitoken_issuer=None, container=None, time_reference='geocent', plot_data=False, plot_injection=False, plot_spectrogram=False, plot_corner=True, plot_weights=True, plot_log_probs=True, plot_pp=False, create_summary=False, email=None, notification='Never', queue=None, existing_dir=None, webdir=None, summarypages_arguments=None, result_format='hdf5', final_result=True, final_result_nsamples=20000, default_prior='BBHPriorDict', deltaT=0.0, Toffset=0.011423417367041111, prior_dict_updates=None, prior_file=None, prior_dict="{a_1:DeltaFunction(peak=0.925635814666748, name=None, latex_label=None, unit=None), a_2:DeltaFunction(peak=0.5538952350616455, name=None, latex_label=None, unit=None), chirp_mass:bilby.gw.prior.UniformInComponentsChirpMass(minimum=15.0, maximum=50.0, name='chirp_mass', latex_label='$\\\\mathcal{M}$', unit=None, boundary=None), luminosity_distance:DeltaFunction(peak=488.2327880859375, name=None, latex_label=None, unit=None), mass_ratio:bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False), phase:DeltaFunction(peak=0.9604566579018894, name=None, latex_label=None, unit=None), phi_jl:DeltaFunction(peak=5.561878204345703, name=None, latex_label=None, unit=None), theta_jn:DeltaFunction(peak=2.624497413635254, name=None, latex_label=None, unit=None), tilt_1:DeltaFunction(peak=2.0111560821533203, name=None, latex_label=None, unit=None), tilt_2:DeltaFunction(peak=1.0743615627288818, name=None, latex_label=None, uni ...
# 260331_185157 INFO: Unknown command line arguments: []
# 260331_185157 INFO: Generation seed set to 665497
# 260331_185157 INFO: Setting PSD for H1 from data
# 260331_185157 INFO: Using default PSD start time -512.0 relative to start time
# 260331_185157 INFO: Getting psd-segment data for H1
# 260331_185157 INFO: Attempting to download data from GWOSC
# 260331_185157 INFO: Running: gwpy.timeseries.TimeSeries.fetch_open_data(ifo='H1', start=1126258948.3885767, end=1126259460.3885767, sample_rate=16384, )
# 260331_190302 INFO: Resampling data to sampling_frequency 2048.0 using lal
# 260331_190304 INFO: PSD settings: window=Tukey, Tukey-alpha=0.5 roll-off=1.0, overlap=0.0, method=median
# 260331_190304 INFO: Getting analysis-segment data for H1
# 260331_190304 INFO: Attempting to download data from GWOSC
# 260331_190304 INFO: Running: gwpy.timeseries.TimeSeries.fetch_open_data(ifo='H1', start=1126259460.3885767, end=1126259464.3885767, sample_rate=16384, )
# 260331_191553 INFO: Resampling data to sampling_frequency 2048.0 using lal
# 260331_191553 INFO: Setting PSD for L1 from data
# 260331_191553 INFO: Using default PSD start time -512.0 relative to start time
# 260331_191553 INFO: Getting psd-segment data for L1
# 260331_191553 INFO: Attempting to download data from GWOSC
# 260331_191553 INFO: Running: gwpy.timeseries.TimeSeries.fetch_open_data(ifo='L1', start=1126258948.3885767, end=1126259460.3885767, sample_rate=16384, )
# 260331_192847 INFO: Resampling data to sampling_frequency 2048.0 using lal
# 260331_192849 INFO: PSD settings: window=Tukey, Tukey-alpha=0.5 roll-off=1.0, overlap=0.0, method=median
# 260331_192849 INFO: Getting analysis-segment data for L1
# 260331_192849 INFO: Attempting to download data from GWOSC
# 260331_192849 INFO: Running: gwpy.timeseries.TimeSeries.fetch_open_data(ifo='L1', start=1126259460.3885767, end=1126259464.3885767, sample_rate=16384, )
# Traceback (most recent call last):
#   File "/home/yyyz/miniconda3/envs/dingo/bin/dingo_pipe_generation", line 6, in <module>
#     sys.exit(main())
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/dingo/pipe/data_generation.py", line 537, in main
#     data = DataGenerationInput(args, unknown_args)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/dingo/pipe/data_generation.py", line 213, in __init__
#     self.create_data(args)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/data_generation.py", line 263, in create_data
#     self._set_interferometers_from_data()
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/data_generation.py", line 546, in _set_interferometers_from_data
#     data = self._get_data(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/data_generation.py", line 692, in _get_data
#     data = self._gwpy_fetch_open_data(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/data_generation.py", line 1016, in _gwpy_fetch_open_data
#     data = gwpy.timeseries.TimeSeries.fetch_open_data(**kwargs)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/gwpy/timeseries/core.py", line 475, in fetch_open_data
#     return fetch_gwosc_data(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/gwpy/timeseries/io/losc.py", line 194, in fetch_gwosc_data
#     new = _fetch_gwosc_data_file(url, *args, **kwargs)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/gwpy/timeseries/io/losc.py", line 94, in _fetch_gwosc_data_file
#     with _download_file(url, cache, verbose=verbose, timeout=timeout) as rem:
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/contextlib.py", line 135, in __enter__
#     return next(self.gen)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/astropy/utils/data.py", line 358, in get_readable_fileobj
#     name_or_obj = download_file(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/astropy/utils/data.py", line 1563, in download_file
#     raise errors[sources[0]]
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/astropy/utils/data.py", line 1531, in download_file
#     f_name = _download_file_from_source(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/astropy/utils/data.py", line 1315, in _download_file_from_source
#     with _try_url_open(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/astropy/utils/data.py", line 1229, in _try_url_open
#     return urlopener.open(req, timeout=timeout)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/urllib/request.py", line 525, in open
#     response = meth(req, response)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/urllib/request.py", line 563, in error
#     return self._call_chain(*args)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/urllib/request.py", line 643, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Proxy Error
# Traceback (most recent call last):
#   File "/home/yyyz/miniconda3/envs/dingo/bin/dingo_pipe", line 6, in <module>
#     sys.exit(main())
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/dingo/pipe/main.py", line 628, in main
#     generate_dag(inputs)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/dingo/pipe/dag_creator.py", line 103, in generate_dag
#     generation_node = GenerationNode(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/dingo/pipe/nodes/generation_node.py", line 121, in __init__
#     self.process_node()
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/job_creation/node.py", line 50, in process_node
#     subprocess.run([self.executable] + self.arguments.argument_list, check=True)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/subprocess.py", line 526, in run
#     raise CalledProcessError(retcode, process.args,
# subprocess.CalledProcessError: Command '['/home/yyyz/miniconda3/envs/dingo/bin/dingo_pipe_generation', '03_inference/outdir_GW150914/GW150914_config_complete.ini', '--importance-sampling-generation', '--label', 'GW150914_data0_1126259462-3885767_generation_IS', '--idx', '0', '--trigger-time', '1126259462.3885767', '--outdir', '03_inference/outdir_GW150914']' returned non-zero exit status 1.

# %% [markdown]
# This script produces several files in the folder `03_inference/outdir_GW150914`, where `results` contains the generated (importance) samples, and different plots.
#
# The officially reported values are: chirp mass $\mathcal{M}_c = 27.6^{+2.0}_{-2.0} M_{⊙}$, and mass ratio $q = 0.82^{+0.17}_{-0.20}$ (from [GWOSC](https://gwosc.org/events/GW150914/#P150914), [arXiV:1602.03837](https://arxiv.org/abs/1602.03837)). Similar to the injections, we don't expect good results from this simplified toy setting.

# %%
from dingo.gw.result import Result

# Adjust path as needed
result = Result(file_name="03_inference/outdir_GW150914/result/GW150914_data0_1126259462-3885767_importance_sampling.hdf5")
result.samples.describe()
# Out:
# Loading dataset from 03_inference/outdir_GW150914/result/GW150914_data0_1126259462-3885767_importance_sampling.hdf5.
# /home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#         chirp_mass   mass_ratio     log_prob          a_1          a_2  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean     36.252720     0.297999    -2.647782     0.925636     0.553895
# std      10.004034     0.246792     1.853153     0.000000     0.000000
# min       1.064743    -0.450460   -10.274813     0.925636     0.553895
# 25%      27.625530     0.180457    -3.952554     0.925636     0.553895
# 50%      38.390429     0.201207    -2.542974     0.925636     0.553895
# 75%      43.286049     0.284470    -1.197355     0.925636     0.553895
# max      69.851357     1.382413     1.101378     0.925636     0.553895
#
#        geocent_time  luminosity_distance        phase       phi_jl  \
# count   5000.000000          5000.000000  5000.000000  5000.000000
# mean       0.011423           488.232788     0.960457     5.561878
# std        0.000000             0.000000     0.000000     0.000000
# min        0.011423           488.232788     0.960457     5.561878
# 25%        0.011423           488.232788     0.960457     5.561878
# 50%        0.011423           488.232788     0.960457     5.561878
# 75%        0.011423           488.232788     0.960457     5.561878
# max        0.011423           488.232788     0.960457     5.561878
#
#           theta_jn       tilt_1       tilt_2          dec           ra  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      2.624497     2.011156     1.074362    -1.261601     1.455775
# std       0.000000     0.000000     0.000000     0.000000     0.000000
# min       2.624497     2.011156     1.074362    -1.261601     1.455775
# 25%       2.624497     2.011156     1.074362    -1.261601     1.455775
# 50%       2.624497     2.011156     1.074362    -1.261601     1.455775
# 75%       2.624497     2.011156     1.074362    -1.261601     1.455775
# max       2.624497     2.011156     1.074362    -1.261601     1.455775
#
#                psi    log_prior  log_likelihood        weights
# count  5000.000000  5000.000000     4051.000000   5.000000e+03
# mean      1.212448         -inf     -409.736688   1.000000e+00
# std       0.000000          NaN      120.487784   2.723656e+01
# min       1.212448         -inf     -872.030906   0.000000e+00
# 25%       1.212448    -4.076732     -389.182865  1.488568e-157
# 50%       1.212448    -2.865429     -359.081380   4.894411e-23
# 75%       1.212448    -2.457730     -339.164215   3.230108e-09
# max       1.212448    -1.706114     -318.507465   1.418931e+03

# %%
result.print_summary()
# Out:
# Number of samples: 5000
# Log(evidence): -324.501 +- 0.385
# Effective samples 6.7: (Sample efficiency = 0.13%)

# %% [markdown]
# **Exercises**:
# 1. Replace the delta function over the luminosity distance in the prior of the DINGO model by a Uniform distribution over $d_L \in [100, 1000]$ Mpc.
# 2. Train a marginalized model & perform inference.
# 3. Train a model that infers the luminosity distance as well.
#
# You can use the folder `04_exercise` and its subfolders to save the settings files and models.

# %% [markdown]
# # 6. Inference with a pre-trained DINGO model (from Zenodo)
#
# Larger networks are more expensive to train, often ~ week on an A100. We therefore supply some pre-trained networks on Zenodo. These production models rely on the algorithm ["Group Equivariant Neural Posterior Estimation" (GNPE)](https://dingo-gw.readthedocs.io/en/latest/gnpe.html) which includes (approximate) joint symmetries of data and parameters in the `dingo` model and simplifies the data subject to time shifts.
#
# Practically, this this means that instead of one `dingo` model, we must specify two separate models:
# 1. **Initialization model**: Learns a proxy for the arrival times of the signal in each detector and acts as a starting point for the Gibbs sampler. Based on the output of this model, the strain data is transformed and simplified before serving as an input to the main model.
# 2. **Main model**: Conditioned on the proxy variable and learns the full posterior distribution.
#
#
# **Step 1: Download trained DINGO model from Zenodo**
#
# Use the [O1 GNPE networks](https://zenodo.org/records/12156303), which are based on `IMRPhenomXPHM` and a luminosity distance prior of $d_L \in [100 - 1000]$ Mpc.
# The following download might take some time depending on the internet connection.

# %%
# !wget -q --directory-prefix=05_pretrained_model/init_train_dir https://zenodo.org/records/12156303/files/model_init.pt # init model
# !wget -q --directory-prefix=05_pretrained_model/main_train_dir https://zenodo.org/records/12156303/files/model.pt # main model

# %% [markdown]
# **Step 2: Prepare INI file**
#
# For GNPE, the `GW150914.ini` file has to be adapted to specify the path to the initial and the main models. We also must include `num_gnpe_iterations` to specify the number of Gibbs sampling iterations.
#
# We set `recover-log-prob = False` and `importance-sample = False`, to speed up execution for the tutorial. If you change these values to `True`, the log probability values have to be recovered for importance sampling with GNPE which takes more time.

# %%
dingo_pipe_GW150914 = """
################################################################################
##  Job submission arguments
################################################################################

local = True
submit = False
accounting = dingo
request-cpus-importance-sampling = 2
simple-submission = False

################################################################################
##  Sampler arguments
################################################################################

model-init = 05_pretrained_model/init_train_dir/model_init.pt
model = 05_pretrained_model/main_train_dir/model.pt
device = cuda
num-gnpe-iterations = 10 #30
num-samples = 10_000
batch-size = 5000
recover-log-prob = False #True
prior-dict-updates = {
luminosity_distance = bilby.gw.prior.UniformComovingVolume(minimum=100, maximum=2000, name='luminosity_distance'),
}
importance-sample = False #True

################################################################################
## Data generation arguments
################################################################################

trigger-time = GW150914
label = GW150914
outdir = 05_pretrained_model/outdir_GW150914
channel-dict = {H1:GWOSC, L1:GWOSC}
psd-length = 128
# sampling-frequency = 2048.0
# importance-sampling-updates = {'duration': 4.0}

################################################################################
## Plotting arguments
################################################################################

plot-corner = true
plot-weights = true
plot-log-probs = true
"""
with open('05_pretrained_model/GW150914.ini', 'w') as outfile:
    outfile.write(dingo_pipe_GW150914)

# %% [markdown]
# **Step 3: Run `dingo_pipe` on pretrained DINGO model**
#
# Finally, we can run `dingo_pipe` with the specified `.ini` file to obtain the results for the complete posterior distribution.

# %% [markdown]
# Due to a recent change in the window factor usage, the current models on Zenodo are not compatible with `dingo-gw>=0.9.0` and we expect low sample efficiency. If you want to run inference with the GNPE models, downgrade the package to `dingo-gw==0.8.7`.
# The following code illustrates the usage of `dingo_pipe` and showcases how inference works in principle.

# %%
# !dingo_pipe 05_pretrained_model/GW150914.ini
# Out:
# 260331_194849 INFO: Loading dingo model from 05_pretrained_model/main_train_dir/model.pt in order to access settings.
#
# ========
# WARNING!
#
# This object was created using Dingo version 0.3.2 < 0.9.0, which broke backwards compatibility.
# For models trained prior to this change, new inference results will be unreliable.
# Previously-generated result files should be used with caution.
# Reasons for backward compatibility breaking:
#
# v0.9.0: Change to window factor usage, see https://git.ligo.org/pe/pe-group-coordination/-/issues/1#note_1469386.
# =======
#
# Setting spin_conversion_phase = 0.0. Using this value for the phase parameter for conversion to cartesian spins.
# 260331_194853 INFO: Setting analysis request_cpus_importance_sampling = 2
# 260331_194853 INFO: Using a non-'dingo' accounting tag: please ensure this is intentional
# 260331_194853 INFO: Using accounting tag: dingo.GW150914
# 260331_194853 INFO: Using accounting-user: None
# 260331_194853 INFO: Setting segment trigger-times [1126259462.4]
# 260331_194853 INFO: Skipping datafind for H1 as GWOSC data is used.
# 260331_194853 INFO: Skipping datafind for L1 as GWOSC data is used.
# 260331_194853 INFO: Running command: /home/yyyz/miniconda3/envs/dingo/bin/dingo_pipe_generation 05_pretrained_model/outdir_GW150914/GW150914_config_complete.ini --label GW150914_data0_1126259462-4_generation --idx 0 --trigger-time 1126259462.4 --outdir 05_pretrained_model/outdir_GW150914
# 260331_194855 WARNING: You do not have nds2 (python-nds2-client) installed. You may  experience problems accessing interferometer data.
# 260331_194855 WARNING: You do not have LDAStools.frameCPP (python-ldas-tools-framecpp) installed. You may experience problems accessing interferometer data.
# 260331_194856 INFO: Command line arguments: Namespace(ini='05_pretrained_model/outdir_GW150914/GW150914_config_complete.ini', verbose=False, calibration_model=None, calibration_mode='marginalize', calibration_correction_type=None, spline_calibration_envelope_dict=None, spline_calibration_nodes=10, spline_calibration_curves=1000, idx=0, data_dump_file=None, event_data_file=None, proposal_samples_file=None, importance_sampling_generation=False, ignore_gwpy_data_quality_check=True, gps_tuple=None, gps_file=None, timeslide_file=None, timeslide_dict=None, trigger_time='1126259462.4', n_simulation=0, data_dict=None, data_format=None, allow_tape=True, channel_dict='{H1:GWOSC, L1:GWOSC}', fetch_open_data_kwargs=None, frame_type_dict=None, data_find_url=None, data_find_urltype='osdf', gaussian_noise=False, zero_noise=False, detectors=['H1', 'L1'], duration=8.0, generation_seed=None, psd_dict=None, asd_dataset=None, psd_fractional_overlap=0.0, post_trigger_duration=2.0, sampling_frequency=4096.0, psd_length=128, psd_maximum_duration=1024, psd_method='median', psd_start_time=None, maximum_frequency='1024.0', minimum_frequency='20.0', tukey_roll_off=1.0, resampling_method='lal', injection=False, injection_dict=None, injection_file=None, injection_numbers=[None], dingo_injection=False, injection_waveform_approximant=None, injection_frequency_domain_source_model=None, injection_waveform_arguments=None, injection_waveform_generator_constructor_dict=None, save_bilby_data_dump=False, accounting='dingo.GW150914', accounting_user=None, label='GW150914_data0_1126259462-4_generation', local=True, local_generation=False, generation_pool='local-pool', local_plot=False, outdir='05_pretrained_model/outdir_GW150914', overwrite_outdir=False, request_disk=5.0, request_memory_generation=8.0, request_memory=8.0, request_cpus=1, request_memory_importance_sampling=8.0, request_cpus_importance_sampling=2, conda_env=None, sampling_requirements=['None'], extra_lines=['None'], simple_submission=False, scheduler='condor', scheduler_args=None, scheduler_module=[None], scheduler_env=None, scheduler_analysis_time='7-00:00:00', submit=False, condor_job_priority=0, transfer_files=True, environment_variables=None, getenv=[None], additional_transfer_paths=[None], disable_hdf5_locking=False, log_directory=None, osg=False, gpu_desired_sites=None, cpu_desired_sites=None, generation_desired_sites=None, analysis_executable=None, analysis_executable_parser=None, scitoken_issuer=None, container=None, time_reference='geocent', plot_data=False, plot_injection=False, plot_spectrogram=False, plot_corner=True, plot_weights=True, plot_log_probs=True, plot_pp=False, create_summary=False, email=None, notification='Never', queue=None, existing_dir=None, webdir=None, summarypages_arguments=None, result_format='hdf5', final_result=True, final_result_nsamples=20000, default_prior='BBHPriorDict', deltaT=0.2, Toffset=0.0, prior_dict_updates="{luminosity_distance = bilby.gw.prior.UniformComovingVolume(minimum=100, maximum=2000, name='luminosity_distance'), }", prior_file=None, prior_dict="{mass_1:Constraint(minimum=10.0, maximum=80.0, name=None, latex_label=None, unit=None), mass_2:Constraint(minimum=10.0, maximum=80.0, name=None, latex_label=None, unit=None), chirp_mass:bilby.gw.prior.UniformInComponentsChirpMass(minimum=15.0, maximum=100.0, name='chirp_mass', latex_label='$\\\\mathcal{M}$', unit=None, boundary=None), mass_ratio:bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False), phase:Uniform(minimum=0.0, maximum=6.283185307179586, name='phase', latex_label='$\\\\phi$', unit=None, boundary='periodic'), a_1:Uniform(minimum=0.0, maximum=0.99, name=None, latex_label=None, unit=None, boundary=None), a_2:Uniform(minimum=0.0, maximum=0.99, name=None, latex_label=None, unit=None, boundary=None), tilt_1:Sine(minimum=0.0, maximum=3.141592653589793, name='tilt_1', latex_label='$\\\\theta_1$', unit= ...
# 260331_194856 INFO: Unknown command line arguments: []
# 260331_194856 INFO: Generation seed set to 714472
# 260331_194856 INFO: Setting PSD for H1 from data
# 260331_194856 INFO: Using default PSD start time -1024.0 relative to start time
# 260331_194856 INFO: Getting psd-segment data for H1
# 260331_194856 INFO: Attempting to download data from GWOSC
# 260331_194856 INFO: Running: gwpy.timeseries.TimeSeries.fetch_open_data(ifo='H1', start=1126258432.4, end=1126259456.4, sample_rate=16384, )
# Traceback (most recent call last):
#   File "/home/yyyz/miniconda3/envs/dingo/bin/dingo_pipe_generation", line 6, in <module>
#     sys.exit(main())
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/dingo/pipe/data_generation.py", line 537, in main
#     data = DataGenerationInput(args, unknown_args)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/dingo/pipe/data_generation.py", line 213, in __init__
#     self.create_data(args)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/data_generation.py", line 263, in create_data
#     self._set_interferometers_from_data()
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/data_generation.py", line 539, in _set_interferometers_from_data
#     psd_data = self.__get_psd_data(det)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/data_generation.py", line 568, in __get_psd_data
#     psd_data = self._get_data(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/data_generation.py", line 692, in _get_data
#     data = self._gwpy_fetch_open_data(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/data_generation.py", line 1016, in _gwpy_fetch_open_data
#     data = gwpy.timeseries.TimeSeries.fetch_open_data(**kwargs)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/gwpy/timeseries/core.py", line 475, in fetch_open_data
#     return fetch_gwosc_data(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/gwpy/timeseries/io/losc.py", line 194, in fetch_gwosc_data
#     new = _fetch_gwosc_data_file(url, *args, **kwargs)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/gwpy/timeseries/io/losc.py", line 94, in _fetch_gwosc_data_file
#     with _download_file(url, cache, verbose=verbose, timeout=timeout) as rem:
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/contextlib.py", line 135, in __enter__
#     return next(self.gen)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/astropy/utils/data.py", line 358, in get_readable_fileobj
#     name_or_obj = download_file(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/astropy/utils/data.py", line 1531, in download_file
#     f_name = _download_file_from_source(
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/astropy/utils/data.py", line 1358, in _download_file_from_source
#     block = remote.read(conf.download_block_size)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/http/client.py", line 471, in read
#     s = self.fp.read(amt)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/socket.py", line 717, in readinto
#     return self._sock.recv_into(b)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/ssl.py", line 1307, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/ssl.py", line 1163, in read
#     return self._sslobj.read(len, buffer)
# TimeoutError: The read operation timed out
# Traceback (most recent call last):
#   File "/home/yyyz/miniconda3/envs/dingo/bin/dingo_pipe", line 6, in <module>
#     sys.exit(main())
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/dingo/pipe/main.py", line 628, in main
#     generate_dag(inputs)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/dingo/pipe/dag_creator.py", line 67, in generate_dag
#     generation_node = GenerationNode(inputs, **kwargs)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/dingo/pipe/nodes/generation_node.py", line 121, in __init__
#     self.process_node()
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/site-packages/bilby_pipe/job_creation/node.py", line 50, in process_node
#     subprocess.run([self.executable] + self.arguments.argument_list, check=True)
#   File "/home/yyyz/miniconda3/envs/dingo/lib/python3.10/subprocess.py", line 526, in run
#     raise CalledProcessError(retcode, process.args,
# subprocess.CalledProcessError: Command '['/home/yyyz/miniconda3/envs/dingo/bin/dingo_pipe_generation', '05_pretrained_model/outdir_GW150914/GW150914_config_complete.ini', '--label', 'GW150914_data0_1126259462-4_generation', '--idx', '0', '--trigger-time', '1126259462.4', '--outdir', '05_pretrained_model/outdir_GW150914']' returned non-zero exit status 1.

# %% [markdown]
# The full 14-dimensional corner plot based on DINGO samples can be found in `05_pretrained_model/outdir_GW150914/results`.
#
# **Exercises:**
# 1. Run an injection with the GNPE model. You can find some hints in the [GNPE](https://dingo-gw.readthedocs.io/en/latest/gnpe.html) and [injection](https://dingo-gw.readthedocs.io/en/latest/example_injection.html) docs.
#
# You will need to use the `GNPESampler` class that can be imported via
# `from dingo.core.samplers import GNPESampler`.
